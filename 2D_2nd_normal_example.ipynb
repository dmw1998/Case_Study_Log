# %% [markdown]
# <a href="https://colab.research.google.com/github/dmw1998/Case_Study_Log/blob/main/2D_2nd_normal_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chaospy
# !pip install casadi
import chaospy as cp
from chaospy.expansion import stieltjes
import numpy as np
import casadi as ca
import matplotlib.pyplot as plt

# %%
# Example: 2 Gaussian random variables
dist = cp.J(cp.Normal(0, 1), cp.Normal(0, 1))

# Polynomial basis up to order 2
poly_expansion, _ = stieltjes(order=2, dist=dist, retall=True)

# Define the expansion coefficients c_i(z, t) (example: time-only for now)
def c0(t): return -10*np.exp(-((t-2.5)**2))
def c1(t): return 5*np.sin(t)
def c2(t): return 3*np.cos(t)

# Evaluate the wind shear k(t, ξ) for given ξ
def windshear_pce(t, xi):
    return c0(t) + c1(t)*xi[0] + c2(t)*xi[1]

# %%
# Quadrature (Gauss-Hermite or Sparse Grid)
samples = dist.sample(50, rule="halton")  # 50 samples, low-discrepancy

# Generate corresponding wind shear profiles
time_grid = np.linspace(0, 50, 100)
windshear_profiles = np.array([
    [windshear_pce(t, sample) for t in time_grid] for sample in samples.T
])

# %%
def solve_ocp(wind_profile, time_grid):
    N = len(time_grid)
    dt = time_grid[1] - time_grid[0]

    x = ca.MX.sym("x", 2)  # state: [altitude, velocity]
    u = ca.MX.sym("u")     # control: pitch angle
    w = ca.MX.sym("w")     # wind shear

    A = ca.Function("A", [x, u, w], [
        ca.vertcat(x[1], -9.81 + u + w)  # simple 1D vertical dynamics
    ])

    # Build integrator
    X = [ca.MX(x)]
    U = []
    for i in range(N-1):
        w_i = wind_profile[i]
        u_i = ca.MX.sym(f"u_{i}")
        U.append(u_i)
        x_next = X[-1] + dt * A(X[-1], u_i, w_i)
        X.append(x_next)

    # Objective: minimize final vertical speed
    obj = ca.sumsqr(X[-1][1])
    # obj = ca.sumsqr(X[-1][1]) + 10 * ca.fmax(0, 1000 - X[-1][0])**2

    # NLP setup
    u_var = ca.vertcat(*U)
    nlp = {'x': u_var, 'f': obj, 'p': X[0]}
    solver = ca.nlpsol('solver', 'ipopt', nlp)
    sol = solver(x0=1000.0, p=[0,0])
    # return float(sol['x'][0])

    u_opt = sol['x'].full().flatten()
    x_val = np.array([1000.0, 20.0])  # initial state
    traj = [x_val.copy()]
    for i in range(N-1):
        w_i = wind_profile[i]
        x_dot = np.array([x_val[1], -9.81 + u_opt[i] + w_i])
        x_val = x_val + dt * x_dot
        traj.append(x_val.copy())
    traj = np.array(traj)

    return u_opt, traj

# %%
results = [solve_ocp(w, time_grid) for w in windshear_profiles]
controls = [r[0] for r in results]
trajectories = [r[1] for r in results]
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4493889e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3950588e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6055827e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1509540e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3030156552658765e-15    3.1509540350477927e-12
# Dual infeasibility......:   3.5866760869524172e-09    1.7930229126355270e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5866760869524172e-09    1.7930229126355270e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.026
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 593.00us (148.25us) 581.98us (145.49us)         4
#   nlp_grad_f  |   1.15ms (229.20us)   1.14ms (228.87us)         5
#   nlp_hess_l  |  18.76ms (  6.25ms)  18.77ms (  6.26ms)         3
#        total  |  26.65ms ( 26.65ms)  26.57ms ( 26.57ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4493955e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3950715e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6056035e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1509875e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3030742952982511e-15    3.1509875384571331e-12
# Dual infeasibility......:   3.5866903873524687e-09    1.7930324450216310e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5866903873524687e-09    1.7930324450216310e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.026
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 642.00us (160.50us) 635.20us (158.80us)         4
#   nlp_grad_f  |   1.07ms (213.80us)   1.07ms (213.52us)         5
#   nlp_hess_l  |  18.81ms (  6.27ms)  18.68ms (  6.23ms)         3
#        total  |  26.43ms ( 26.43ms)  26.23ms ( 26.23ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4494763e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3952296e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6058616e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1514037e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3038027615983615e-15    3.1514037421628367e-12
# Dual infeasibility......:   3.5868680314935397e-09    1.7931508590263831e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5868680314935397e-09    1.7931508590263831e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.027
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 670.00us (167.50us) 660.06us (165.01us)         4
#   nlp_grad_f  |   1.25ms (249.80us)   1.25ms (249.29us)         5
#   nlp_hess_l  |  18.82ms (  6.27ms)  18.89ms (  6.30ms)         3
#        total  |  27.58ms ( 27.58ms)  27.51ms ( 27.51ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4494829e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3952423e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6058823e-04 0.00e+00 3.26e-05  -2.5 9.79e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1514371e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3038611947810308e-15    3.1514371432095767e-12
# Dual infeasibility......:   3.5868822717695845e-09    1.7931603616102880e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5868822717695845e-09    1.7931603616102880e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.025
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 578.00us (144.50us) 569.17us (142.29us)         4
#   nlp_grad_f  |   1.11ms (222.00us)   1.11ms (222.27us)         5
#   nlp_hess_l  |  18.63ms (  6.21ms)  18.54ms (  6.18ms)         3
#        total  |  26.25ms ( 26.25ms)  26.09ms ( 26.09ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4492697e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3948257e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6052024e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1503406e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3019419996661703e-15    3.1503406133823081e-12
# Dual infeasibility......:   3.5864142477000491e-09    1.7928483730159573e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5864142477000491e-09    1.7928483730159573e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.025
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 564.00us (141.00us) 553.32us (138.33us)         4
#   nlp_grad_f  |   1.14ms (227.80us)   1.14ms (227.62us)         5
#   nlp_hess_l  |  18.65ms (  6.22ms)  18.67ms (  6.22ms)         3
#        total  |  26.12ms ( 26.12ms)  26.07ms ( 26.07ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4495752e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3954229e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6061770e-04 0.00e+00 3.26e-05  -2.5 9.79e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1519124e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3046930463165841e-15    3.1519124341651016e-12
# Dual infeasibility......:   3.5870851064624982e-09    1.7932955762331758e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5870851064624982e-09    1.7932955762331758e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.038
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 835.00us (208.75us) 826.10us (206.53us)         4
#   nlp_grad_f  |   1.78ms (355.60us)   1.77ms (354.38us)         5
#   nlp_hess_l  |  28.21ms (  9.40ms)  28.69ms (  9.56ms)         3
#        total  |  38.83ms ( 38.83ms)  39.27ms ( 39.27ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4494359e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3951506e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6057327e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1511959e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3034389947145372e-15    3.1511958962840310e-12
# Dual infeasibility......:   3.5867793300366954e-09    1.7930917258286057e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5867793300366954e-09    1.7930917258286057e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.026
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 646.00us (161.50us) 622.42us (155.61us)         4
#   nlp_grad_f  |   1.07ms (215.00us)   1.07ms (214.61us)         5
#   nlp_hess_l  |  18.97ms (  6.32ms)  18.99ms (  6.33ms)         3
#        total  |  28.40ms ( 28.40ms)  26.97ms ( 26.97ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4494407e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3951598e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6057477e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1512200e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3034810599822966e-15    3.1512199569425894e-12
# Dual infeasibility......:   3.5867895727214980e-09    1.7930985713067744e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5867895727214980e-09    1.7930985713067744e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.026
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 668.00us (167.00us) 656.89us (164.22us)         4
#   nlp_grad_f  |   1.04ms (207.20us)   1.03ms (206.68us)         5
#   nlp_hess_l  |  18.83ms (  6.28ms)  18.84ms (  6.28ms)         3
#        total  |  26.47ms ( 26.47ms)  26.46ms ( 26.46ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4494686e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3952145e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6058370e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1513639e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3037329844214855e-15    3.1513639077562212e-12
# Dual infeasibility......:   3.5868509975801669e-09    1.7931395260884282e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5868509975801669e-09    1.7931395260884282e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.026
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 584.00us (146.00us) 563.06us (140.76us)         4
#   nlp_grad_f  |   1.08ms (217.00us)   1.09ms (217.12us)         5
#   nlp_hess_l  |  20.98ms (  6.99ms)  19.57ms (  6.52ms)         3
#        total  |  28.59ms ( 28.59ms)  27.01ms ( 27.01ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4494636e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3952048e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6058210e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1513382e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3036880725594490e-15    3.1513382347713080e-12
# Dual infeasibility......:   3.5868400528917833e-09    1.7931322220545072e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5868400528917833e-09    1.7931322220545072e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.028
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 583.00us (145.75us) 572.16us (143.04us)         4
#   nlp_grad_f  |   1.12ms (225.00us)   1.12ms (224.91us)         5
#   nlp_hess_l  |  20.60ms (  6.87ms)  20.63ms (  6.88ms)         3
#        total  |  28.29ms ( 28.29ms)  28.26ms ( 28.26ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4493621e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3950063e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6054972e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1508160e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3027740770982672e-15    3.1508160163516835e-12
# Dual infeasibility......:   3.5866171707116381e-09    1.7929836430378525e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5866171707116381e-09    1.7929836430378525e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.025
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 568.00us (142.00us) 555.40us (138.85us)         4
#   nlp_grad_f  |   1.06ms (211.20us)   1.05ms (210.75us)         5
#   nlp_hess_l  |  18.34ms (  6.11ms)  18.37ms (  6.12ms)         3
#        total  |  25.78ms ( 25.78ms)  25.73ms ( 25.73ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4495598e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3953927e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6061277e-04 0.00e+00 3.26e-05  -2.5 9.79e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1518330e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3045539723185675e-15    3.1518329619922210e-12
# Dual infeasibility......:   3.5870512018053919e-09    1.7932729680552198e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5870512018053919e-09    1.7932729680552198e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.027
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 658.00us (164.50us) 646.50us (161.62us)         4
#   nlp_grad_f  |   1.44ms (288.60us)   1.44ms (288.90us)         5
#   nlp_hess_l  |  19.87ms (  6.62ms)  19.81ms (  6.60ms)         3
#        total  |  27.88ms ( 27.88ms)  27.53ms ( 27.53ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4493260e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3949357e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6053819e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1506301e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3024487116798627e-15    3.1506301090334165e-12
# Dual infeasibility......:   3.5865378299506330e-09    1.7929307466300599e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5865378299506330e-09    1.7929307466300599e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.029
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 678.00us (169.50us) 681.33us (170.33us)         4
#   nlp_grad_f  |   1.27ms (253.20us)   1.27ms (253.34us)         5
#   nlp_hess_l  |  21.35ms (  7.12ms)  21.39ms (  7.13ms)         3
#        total  |  30.14ms ( 30.14ms)  30.14ms ( 30.14ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4493333e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3949501e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6054054e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1506680e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3025150365877165e-15    3.1506680054864119e-12
# Dual infeasibility......:   3.5865540036465424e-09    1.7929415294749350e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5865540036465424e-09    1.7929415294749350e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.025
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 557.00us (139.25us) 547.10us (136.77us)         4
#   nlp_grad_f  |   1.08ms (215.80us)   1.08ms (215.33us)         5
#   nlp_hess_l  |  18.62ms (  6.21ms)  18.63ms (  6.21ms)         3
#        total  |  26.12ms ( 26.12ms)  26.06ms ( 26.06ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4495135e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3953023e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6059802e-04 0.00e+00 3.26e-05  -2.5 9.79e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1515950e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3041375325577422e-15    3.1515950349589015e-12
# Dual infeasibility......:   3.5869496526523528e-09    1.7932052810656487e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5869496526523528e-09    1.7932052810656487e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.029
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 603.00us (150.75us) 589.77us (147.44us)         4
#   nlp_grad_f  |   1.16ms (231.80us)   1.16ms (231.32us)         5
#   nlp_hess_l  |  20.90ms (  6.97ms)  20.95ms (  6.98ms)         3
#        total  |  29.63ms ( 29.63ms)  29.53ms ( 29.53ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4494918e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3952598e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6059108e-04 0.00e+00 3.26e-05  -2.5 9.79e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1514832e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3039417450856089e-15    3.1514831520633907e-12
# Dual infeasibility......:   3.5869019216272698e-09    1.7931734510276044e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5869019216272698e-09    1.7931734510276044e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.027
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 565.00us (141.25us) 552.44us (138.11us)         4
#   nlp_grad_f  |   1.13ms (226.40us)   1.13ms (225.98us)         5
#   nlp_hess_l  |  20.05ms (  6.68ms)  20.14ms (  6.71ms)         3
#        total  |  27.74ms ( 27.74ms)  27.75ms ( 27.75ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4493381e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3949594e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6054206e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1506927e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3025583257488466e-15    3.1506927160261851e-12
# Dual infeasibility......:   3.5865645734838986e-09    1.7929485604388495e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5865645734838986e-09    1.7929485604388495e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.042
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 844.00us (211.00us) 833.36us (208.34us)         4
#   nlp_grad_f  |   1.80ms (360.60us)   1.83ms (365.36us)         5
#   nlp_hess_l  |  31.60ms ( 10.53ms)  31.82ms ( 10.61ms)         3
#        total  |  42.76ms ( 42.76ms)  42.98ms ( 42.98ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4495219e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3953186e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6060068e-04 0.00e+00 3.26e-05  -2.5 9.79e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1516378e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3042124122738571e-15    3.1516378202725324e-12
# Dual infeasibility......:   3.5869679101342515e-09    1.7932174530911013e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5869679101342515e-09    1.7932174530911013e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.039
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 904.00us (226.00us) 891.65us (222.91us)         4
#   nlp_grad_f  |   1.84ms (368.20us)   1.84ms (368.13us)         5
#   nlp_hess_l  |  28.86ms (  9.62ms)  29.06ms (  9.69ms)         3
#        total  |  40.09ms ( 40.09ms)  40.21ms ( 40.21ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# ...
#   nlp_grad_f  |   2.55ms (509.20us)   2.06ms (412.61us)         5
#   nlp_hess_l  |  32.73ms ( 10.91ms)  33.45ms ( 11.15ms)         3
#        total  |  45.70ms ( 45.70ms)  45.80ms ( 45.80ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4494151e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3951099e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6056662e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1510888e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3032514995809418e-15    3.1510887726399125e-12
# Dual infeasibility......:   3.5867336069660031e-09    1.7930612478515614e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5867336069660031e-09    1.7930612478515614e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.040
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 892.00us (223.00us) 883.59us (220.90us)         4
#   nlp_grad_f  |   1.84ms (368.40us)   1.84ms (368.77us)         5
#   nlp_hess_l  |  29.42ms (  9.81ms)  29.59ms (  9.86ms)         3
#        total  |  40.67ms ( 40.67ms)  40.76ms ( 40.76ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4494361e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3951508e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6057330e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1511964e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3034398391452114e-15    3.1511963961836606e-12
# Dual infeasibility......:   3.5867795260342894e-09    1.7930918680549040e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5867795260342894e-09    1.7930918680549040e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.044
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 949.00us (237.25us) 936.35us (234.09us)         4
#   nlp_grad_f  |   1.90ms (379.40us)   1.90ms (379.89us)         5
#   nlp_hess_l  |  32.39ms ( 10.80ms)  33.44ms ( 11.15ms)         3
#        total  |  44.31ms ( 44.31ms)  45.27ms ( 45.27ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4493284e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3949404e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6053897e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1506428e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3024710184086402e-15    3.1506428378523882e-12
# Dual infeasibility......:   3.5865432790869246e-09    1.7929343684242822e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5865432790869246e-09    1.7929343684242822e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.044
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 928.00us (232.00us) 919.75us (229.94us)         4
#   nlp_grad_f  |   1.88ms (376.80us)   1.89ms (377.77us)         5
#   nlp_hess_l  |  32.89ms ( 10.96ms)  32.55ms ( 10.85ms)         3
#        total  |  45.01ms ( 45.01ms)  44.76ms ( 44.76ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4495140e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3953032e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6059817e-04 0.00e+00 3.26e-05  -2.5 9.79e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1515975e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3041418782908764e-15    3.1515975086977442e-12
# Dual infeasibility......:   3.5869507175743307e-09    1.7932059848236882e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5869507175743307e-09    1.7932059848236882e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.027
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 565.00us (141.25us) 554.79us (138.70us)         4
#   nlp_grad_f  |   1.14ms (228.60us)   1.14ms (228.25us)         5
#   nlp_hess_l  |  19.89ms (  6.63ms)  19.76ms (  6.59ms)         3
#        total  |  27.42ms ( 27.42ms)  27.23ms ( 27.23ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4493620e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3950061e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6054968e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1508156e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3027733352627584e-15    3.1508155717605143e-12
# Dual infeasibility......:   3.5866170016094826e-09    1.7929835165397141e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5866170016094826e-09    1.7929835165397141e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.042
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 874.00us (218.50us) 865.90us (216.47us)         4
#   nlp_grad_f  |   1.64ms (327.60us)   1.68ms (335.92us)         5
#   nlp_hess_l  |  28.49ms (  9.50ms)  31.32ms ( 10.44ms)         3
#        total  |  39.87ms ( 39.87ms)  42.88ms ( 42.88ms)         1
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4950
#
# Total number of variables............................:       99
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.4493134e+09 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.3949110e+03 0.00e+00 9.89e-02  -1.0 9.89e+02  -4.0 1.00e+00 1.00e+00f  1
#    2  2.6053417e-04 0.00e+00 3.26e-05  -2.5 9.78e-01  -4.5 1.00e+00 1.00e+00f  1
#    3  3.1505653e-12 0.00e+00 3.59e-09  -5.7 3.23e-04  -5.0 1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.3023352855887693e-15    3.1505652995010890e-12
# Dual infeasibility......:   3.5865101705612168e-09    1.7929123059377647e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.5865101705612168e-09    1.7929123059377647e-06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total seconds in IPOPT                               = 0.026
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 613.00us (153.25us) 601.37us (150.34us)         4
#   nlp_grad_f  |   1.05ms (210.40us)   1.05ms (209.97us)         5
#   nlp_hess_l  |  19.17ms (  6.39ms)  19.10ms (  6.37ms)         3
#        total  |  26.79ms ( 26.79ms)  26.64ms ( 26.64ms)         1

# %%
# Plot all wind shear profiles
for profile in windshear_profiles:
    plt.plot(time_grid, profile, alpha=0.5)
plt.title("Wind Shear Profiles from PCE")
plt.xlabel("Time")
plt.ylabel("W(t)")
plt.show()

# Analyze optimal control statistics
print("Mean control:", np.mean(controls))
print("Worst-case control:", np.max(np.abs(controls)))
# Out:
# Mean control: 10.165185613541386
# Worst-case control: 10.19813620335301

# %%
plt.figure(figsize=(8, 4))
controls = np.array(controls).flatten()
plt.hist(controls, bins=20, edgecolor='black')
plt.title("Distribution of Optimal Controls")
plt.xlabel("Pitch Angle (control u)")
plt.ylabel("Count")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
trajectories = np.array(trajectories)  # shape: (samples, time_steps, 2)
altitudes = trajectories[:, :, 0]      # altitude over time
velocities = trajectories[:, :, 1]     # vertical speed

mean_altitude = np.mean(altitudes, axis=0)
worst_altitude = np.min(altitudes, axis=0)

plt.figure(figsize=(10, 5))
for alt in altitudes:
    plt.plot(time_grid, alt, color='gray', alpha=0.3)
plt.plot(time_grid, mean_altitude, label="Mean Altitude", color='blue', linewidth=2)
plt.plot(time_grid, worst_altitude, label="Worst-Case Altitude", color='red', linewidth=2)
plt.xlabel("Time [s]")
plt.ylabel("Altitude [m]")
plt.title("State Trajectories under Different Windshear Profiles")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def solve_ocp_multistage(wind_profile, time_grid):
    N = len(time_grid)
    dt = time_grid[1] - time_grid[0]

    # Define decision variables: control input at each time step
    u = ca.MX.sym("u", N)

    # Initialize state
    x = ca.MX([1000.0, 10.0])  # initial state: altitude=1000m, vertical speed=10
    states = [x]

    # Define dynamics and simulate forward
    for i in range(N-1):
        w_i = wind_profile[i]
        x_dot = ca.vertcat(x[1], -9.81 + u[i] + w_i)
        x = x + dt * x_dot
        states.append(x)

    # Objective: soft landing (zero vertical speed and positive altitude)
    final_state = states[-1]
    obj = final_state[1]**2  # penalty on final vertical speed

    # Add control effort penalty (optional)
    obj += 0.01 * ca.sumsqr(u)

    # Constraints: keep altitude positive throughout
    g = []
    for state in states:
        g.append(state[0])  # altitude > 0

    # Setup NLP
    nlp = {'x': u, 'f': obj, 'g': ca.vertcat(*g)}
    solver = ca.nlpsol('solver', 'ipopt', nlp, {
        'ipopt.print_level': 0,
        'print_time': 0
    })

    # Solve
    u0 = np.zeros(N)
    lbx = -10 * np.ones(N)
    ubx = 10 * np.ones(N)
    lbg = np.zeros(N)
    ubg = 1e5 * np.ones(N)

    sol = solver(x0=u0, lbx=lbx, ubx=ubx, lbg=lbg, ubg=ubg)
    u_opt = sol['x'].full().flatten()

    # Recompute trajectory using optimal u
    x = np.array([1000.0, 10.0])
    traj = [x.copy()]
    for i in range(N-1):
        w_i = wind_profile[i]
        x_dot = np.array([x[1], -9.81 + u_opt[i] + w_i])
        x = x + dt * x_dot
        traj.append(x.copy())
    traj = np.array(traj)

    return u_opt, traj

# Apply to all wind shear profiles
control_trajectories = []
state_trajectories = []

for profile in windshear_profiles:
    u_opt, traj = solve_ocp_multistage(profile, time_grid)
    control_trajectories.append(u_opt)
    state_trajectories.append(traj)

# Compute mean/worst-case altitude trajectories
state_trajectories = np.array(state_trajectories)  # shape: (samples, time, 2)
altitudes = state_trajectories[:, :, 0]
mean_altitude = np.mean(altitudes, axis=0)
worst_altitude = np.min(altitudes, axis=0)

# Plot
plt.figure(figsize=(10, 6))
for alt in altitudes:
    plt.plot(time_grid, alt, color='gray', alpha=0.2)
plt.plot(time_grid, mean_altitude, label="Mean Trajectory", color="blue", linewidth=2)
plt.plot(time_grid, worst_altitude, label="Worst-Case Trajectory", color="red", linewidth=2)
plt.xlabel("Time [s]")
plt.ylabel("Altitude [m]")
plt.title("Multi-Stage Optimal Abort Trajectories")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def solve_robust_ocp(windshear_profiles, time_grid):
    N = len(time_grid)
    dt = time_grid[1] - time_grid[0]
    M = len(windshear_profiles)  # number of samples

    # Decision variables: control input and minimum altitude
    u = ca.MX.sym("u", N)
    zmin = ca.MX.sym("zmin")  # minimum altitude across all scenarios
    xvar = ca.vertcat(u, zmin)

    # Objective: maximize zmin (i.e. avoid low altitudes)
    obj = -zmin + 0.01 * ca.su===msqr(u)  # maximize min altitude, regularize control

    # Constraints: simulate each wind profile
    g = []
    for profile in windshear_profiles:
        x = ca.MX([1000.0, 10.0])  # initial state
        for i in range(N-1):
            w_i = profile[i]
            x_dot = ca.vertcat(x[1], -9.81 + u[i] + w_i)
            x = x + dt * x_dot
            g.append(x[0] - zmin)  # altitude >= zmin

    # Setup NLP
    nlp = {'x': xvar, 'f': obj, 'g': ca.vertcat(*g)}
    solver = ca.nlpsol('solver', 'ipopt', nlp, {
        'ipopt.print_level': 0,
        'print_time': 0
    })

    # Initial guess and bounds
    u0 = np.zeros(N)
    x0 = np.concatenate([u0, [100.0]])
    lbx = np.concatenate([ -10 * np.ones(N), [0.0] ])
    ubx = np.concatenate([  10 * np.ones(N), [1e4] ])

    lbg = np.zeros(len(g))
    ubg = 1e5 * np.ones(len(g))

    # Solve
    sol = solver(x0=x0, lbx=lbx, ubx=ubx, lbg=lbg, ubg=ubg)
    sol_u = sol['x'].full().flatten()
    u_opt = sol_u[:-1]
    zmin_val = sol_u[-1]

    # Recompute trajectories
    trajectories = []
    for profile in windshear_profiles:
        x = np.array([1000.0, 10.0])
        traj = [x.copy()]
        for i in range(N-1):
            w_i = profile[i]
            x_dot = np.array([x[1], -9.81 + u_opt[i] + w_i])
            x = x + dt * x_dot
            traj.append(x.copy())
        trajectories.append(np.array(traj))

    return u_opt, zmin_val, np.array(trajectories)

# %%
u_opt, zmin_val, state_trajectories = solve_robust_ocp(windshear_profiles, time_grid)

altitudes = state_trajectories[:, :, 0]
mean_altitude = np.mean(altitudes, axis=0)
worst_altitude = np.min(altitudes, axis=0)

plt.figure(figsize=(10, 6))
for alt in altitudes:
    plt.plot(time_grid, alt, color='gray', alpha=0.2)
plt.plot(time_grid, mean_altitude, label="Mean Trajectory", color="blue", linewidth=2)
plt.plot(time_grid, worst_altitude, label="Worst-Case Trajectory", color="red", linewidth=2)
plt.axhline(zmin_val, linestyle='--', color='green', label=f"Optimal zmin = {zmin_val:.1f} m")
plt.xlabel("Time [s]")
plt.ylabel("Altitude [m]")
plt.title("Robust Multi-Stage Optimal Abort Trajectories")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
