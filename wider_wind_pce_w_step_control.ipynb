# %%
import casadi as ca
import chaospy as cp
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
np.random.seed(13)

# %%
def solve_wider_wind_ocp_pce(tf, N, pce_order, k_mean, k_std, s_mean, s_std):
    # Time and discretization
    # tf = tf        # final time [sec]
    # N = N          # number of control intervals
    dt = tf / N    # time step

    # Aircraft physical constants
    m = 4662                # mass [lb sec^2 / ft]
    g = 32.172              # gravity [ft/sec^2]
    delta = 0.03491         # thrust inclination angle [rad]

    # Thrust model coefficients: T = A0 + A1*V + A2*V^2
    A0 = 0.4456e5           # [lb]
    A1 = -0.2398e2          # [lb sec / ft]
    A2 = 0.1442e-1          # [lb sec^2 / ft^2]

    # Aerodynamic model
    rho = 0.2203e-2         # air density [lb sec^2 / ft^4]
    S = 0.1560e4            # reference surface area [ft^2]

    # Wind model 3 beta (smoothing) parameters
    beta0 = 0.4             # initial beta value (approximate)
    beta_dot0 = 0.2         # initial beta rate
    sigma = 3               # time to reach beta = 1 [sec]

    # C_D(alpha) = B0 + B1 * alpha + B2 * alpha**2, D = 0.5 * C_D(α) * ρ * S * V²
    B0 = 0.1552
    B1 = 0.12369            # [1/rad]
    B2 = 2.4203             # [1/rad^2]

    # Lift coefficient: C_L = C0 + C1 * alpha (+ C2 * alpha**2)
    C0 = 0.7125             # baseline lift coefficient
    C1 = 6.0877             # AOA lift slope [1/rad]

    # Lift/drag model optional extensions (if needed)
    C2 = -9.0277            # [rad^-2] — e.g., for moment or drag extension

    # Angle of attack & control constraints
    umax = 0.05236          # max control input (rate of change of alpha) [rad/sec]
    alphamax = 0.3          # max angle of attack [rad]
    alpha_star = 0.20944    # changing pt of AoA

    # Wind model x parameters (piecewise smooth wind)
    a = 6e-8                 # x transition midpoint [ft]
    b = -4e-11               # second transition point [ft]

    # Wind model h parameters (polynomial form)
    c = -np.log(25/30.6)*1e-12      # transition smoothing width [ft]
    d = -8.02881e-8         # polynomial coeff [sec^-1 ft^-2]
    e = 6.28083e-11         # polynomial coeff [sec^-1 ft^-3]

    # Cost function / target altitude
    hR = 1000               # reference altitude [ft]
    h_star = 1000           # used in some wind models

    # Auxiliary
    eps = 1e-6              # to avoid division by zero in V

    # Scaling factors (used if normalizing states)
    xscale = 10000          # [ft]
    hscale = 1000           # [ft]
    Vscale = 240            # [ft/sec]
    gammascale = 0.1        # [rad]
    alphascale = 0.3        # [rad]
    uscale = 0.05           # [rad/sec]

    # PCE parameters
    k_dist = cp.Normal(k_mean, k_std)
    s_dist = cp.Normal(s_mean, s_std)
    joint_dist = cp.J(k_dist, s_dist)
    
    poly_basis = cp.expansion.stieltjes(pce_order, joint_dist)
    nodes, weights = cp.generate_quadrature(pce_order, joint_dist, rule='G')
    # print(poly_basis.shape)     # ((pce_order+1)(pce_order+2)/2, )
    # print(weights.shape)        # ((pce_order+1)^2, )
    # print(nodes.shape)          # (2, (pce_order+1)^2)
    
    M = nodes.shape[1]              # number of PCE samples
    
    weights_dm = ca.DM(weights)   # ((pce_order+1)^2， )
    
    Psi_mat = poly_basis(*nodes)    # (M_poly_basis, (pce_order+1)^2)
    Psi_dm = ca.DM(Psi_mat)         # (M_poly_basis, (pce_order+1)^2)
    

    # Opti instance and scaled variables
    opti = ca.Opti()
    x_s = opti.variable(M, N+1)
    h_s = opti.variable(M, N+1)
    V_s = opti.variable(M, N+1)
    gamma_s = opti.variable(M, N+1)
    alpha_s = opti.variable(M, N+1)
    X_pce = opti.variable(5*(pce_order+1), N+1)
    u_s = opti.variable(N)

    # Unscaled variables for dynamics
    x = x_s * xscale
    h = h_s * hscale
    V = V_s * Vscale
    gamma = gamma_s * gammascale
    alpha = alpha_s * alphascale
    u = u_s * uscale

    def Smooth(x_, x0, x1):
        t = (x_ - x0) / (x1 - x0 + eps)
        return ca.if_else(x_ < x0, 0,
               ca.if_else(x_ > x1, 1, 6*t**5 - 15*t**4 + 10*t**3))

    def A_piecewise(x_, s_):
        A1 = -50 + a * (x_/s_)**3 + b * (x_/s_)**4
        A2 = 0.025 * ((x_/s_) - 2300)
        A3 = 50 - a * (4600 - (x_/s_))**3 - b * (4600 - (x_/s_))**4
        A4 = 50
        s1 = Smooth(x_, 480 * s_, 520 * s_)
        s2 = Smooth(x_, 4080 * s_, 4120 * s_)
        s3 = Smooth(x_, 4580 * s_, 4620 * s_)
        B12 = (1 - s1)*A1 + s1*A2
        B23 = (1 - s2)*A2 + s2*A3
        B34 = (1 - s3)*A3 + s3*A4
        return ca.if_else(x_ <= 500 * s_, B12,
               ca.if_else(x_ <= 4100 * s_, B23,
               ca.if_else(x_ <= 4600 * s_, B34, A4)))

    def B_piecewise(x_, s_):
        B1 = d * (x_/s_)**3 + e * (x_/s_)**4
        B2 = -51 * ca.exp(ca.fmin(-c * ((x_/s_) - 2300)**4, 30))
        B3 = d * (4600 - (x_/s_))**3 + e * (4600 - (x_/s_))**4
        B4 = 0
        s1 = Smooth(x_, 480 * s_, 520 * s_)
        s2 = Smooth(x_, 4080 * s_, 4120 * s_)
        s3 = Smooth(x_, 4580 * s_, 4620 * s_)
        B12 = (1 - s1)*B1 + s1*B2
        B23 = (1 - s2)*B2 + s2*B3
        B34 = (1 - s3)*B3 + s3*B4
        return ca.if_else(x_ <= 500 * s_, B12,
               ca.if_else(x_ <= 4100 * s_, B23,
               ca.if_else(x_ <= 4600 * s_, B34, B4)))

    def wind_x(x_, k_, s_):
        return k_ * A_piecewise(x_, s_)

    def wind_h(x_, h_, k_, s_):
        h_safe = ca.fmax(h_, 10.0)
        return k_ * h_safe / h_star * B_piecewise(x_, s_)

    def C_L(alpha_):
        return ca.if_else(alpha_ > alpha_star, C0 + C1 * alpha_,
                          C0 + C1 * alpha_ + C2 * (alpha_ - alpha_star)**2)
    def beta(t_):
        return ca.if_else(t_ < sigma, beta0 + beta_dot0 * t_, 1.0)

    # Symbolic derivatives
    x_sym = ca.MX.sym("x")
    h_sym = ca.MX.sym("h")
    k_sym = ca.MX.sym("k")
    s_sym = ca.MX.sym("s")
    Wx_expr = wind_x(x_sym, k_sym, s_sym)
    Wh_expr = wind_h(x_sym, h_sym, k_sym, s_sym)
    dWx_dx_fun = ca.Function("dWx_dx", [x_sym, k_sym, s_sym], [ca.gradient(Wx_expr, x_sym)])
    dWh_dx_fun = ca.Function("dWh_dx", [x_sym, h_sym, k_sym, s_sym], [ca.gradient(Wh_expr, x_sym)])
    dWh_dh_fun = ca.Function("dWh_dh", [x_sym, h_sym, k_sym, s_sym], [ca.gradient(Wh_expr, h_sym)])

    def aircraft_ode(X, u_, t_, k_val, s_val):
        x_, h_, V_, gamma_, alpha_ = ca.vertsplit(X)

        T = beta(t_) * (A0 + A1 * V_ + A2 * V_**2)
        D = 0.5 * (B0 + B1 * alpha_ + B2 * alpha_**2) * rho * S * V_**2
        L = 0.5 * rho * S * C_L(alpha_) * V_**2

        Wx = wind_x(x_, k_val, s_val)
        Wh = wind_h(x_, h_, k_val, s_val)
        V_safe = ca.fmax(V_, 1e-3)

        x_dot = V_ * ca.cos(gamma_) + Wx
        h_dot = V_ * ca.sin(gamma_) + Wh

        dWx_dx_val = dWx_dx_fun(x_, k_val, s_val)[0]
        dWh_dx_val = dWh_dx_fun(x_, h_, k_val, s_val)[0]
        dWh_dh_val = dWh_dh_fun(x_, h_, k_val, s_val)[0]

        Wx_dot = dWx_dx_val * x_dot
        Wh_dot = dWh_dx_val * x_dot + dWh_dh_val * h_dot

        V_dot = T / m * ca.cos(alpha_ + delta) - D / m - g * ca.sin(gamma_) - (Wx_dot * ca.cos(gamma_) + Wh_dot * ca.sin(gamma_))
        gamma_dot = T / (m * V_safe) * ca.sin(alpha_ + delta) + L / (m * V_safe) - g / V_safe * ca.cos(gamma_) + (1 / V_safe) * (Wx_dot * ca.sin(gamma_) - Wh_dot * ca.cos(gamma_))
        alpha_dot = u_

        return ca.vertcat(x_dot, h_dot, V_dot, gamma_dot, alpha_dot)

    def rk4_step(f, xk, uk, tk, dt, k_val, s_val):
        k1 = f(xk, uk, tk, k_val, s_val)
        k2 = f(xk + dt/2 * k1, uk, tk + dt/2, k_val, s_val)
        k3 = f(xk + dt/2 * k2, uk, tk + dt/2, k_val, s_val)
        k4 = f(xk + dt * k3, uk, tk + dt, k_val, s_val)
        return xk + dt/6 * (k1 + 2*k2 + 2*k3 + k4)

    J = 0

    # Initial conditions
    opti.subject_to(x_s[:, 0] == 0)
    opti.subject_to(h_s[:, 0] == 600 / hscale)
    opti.subject_to(V_s[:, 0] == 239.7 / Vscale)
    opti.subject_to(gamma_s[:, 0] == -0.03925 / gammascale)
    opti.subject_to(alpha_s[:, 0] == 0.1283 / alphascale)
    opti.subject_to(ca.vec(V_s) >= 1e-2 / Vscale)
    # opti.subject_to(gamma_s[:, -1] == -0.05236 / gammascale)
    opti.subject_to(gamma_s[:, -1] >= 0)
    
    h_ddot_all = [[] for _ in range(N)]
    
    for j in range(M):
        # k_org, s_val = nodes[:, j]
        # k_val = k_org / np.sqrt(s_val)  # Adjust k_val for PCE scaling
        k_val, s_val = nodes[:, j]

        for i in range(N):
            h_physical = h_s[:, i] * hscale
            h_mean = ca.dot(weights_dm, h_physical)

            h_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * h_physical)
            h_high_coeffs = h_pce_coeffs[1:]
            h_std_term = ca.sqrt(ca.sumsqr(h_high_coeffs))

            deviation = hR - h_mean + h_std_term * 12
            scaled_deviation = deviation / hscale
            J += dt * scaled_deviation**6

            tk = i * dt     # New line
            Xk = ca.vertcat(x[j, i], h[j, i], V[j, i], gamma[j, i], alpha[j, i])
            Uk = u[i]
            
            # h_ddot = d^2h/dt^2 = V_dot * sin(gamma) + V * cos(gamma) * gamma_dot + Wh_dot
            ode_out = aircraft_ode(Xk, Uk, tk, k_val, s_val)
            x_dot_k = ode_out[0]
            h_dot_k = ode_out[1]
            V_dot_k = ode_out[2]
            gamma_dot_k = ode_out[3]
            # alpha_dot_k = ode_out[4]
            
            dWh_dx_val = dWh_dx_fun(Xk[0], Xk[1], k_val, s_val)[0]
            dWh_dh_val = dWh_dh_fun(Xk[0], Xk[1], k_val, s_val)[0]
            Wh_dot_k = dWh_dx_val * x_dot_k + dWh_dh_val * h_dot_k
            
            h_ddot_k = V_dot_k * ca.sin(Xk[3]) + Xk[2] * ca.cos(Xk[3]) * gamma_dot_k + Wh_dot_k
            
            h_ddot_all[i].append(h_ddot_k)
            
            Xk_end = rk4_step(aircraft_ode, Xk, Uk, tk, dt, k_val, s_val)
            X_next = ca.vertcat(x[j, i+1], h[j, i+1], V[j, i+1], gamma[j, i+1], alpha[j, i+1])
            opti.subject_to(X_next == Xk_end)

            opti.subject_to(opti.bounded(-1, u_s[i], 1))

            alpha_i = alpha_s[:, i] * alphascale
            alpha_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * alpha_i)
            alpha_high_coeffs = alpha_pce_coeffs[1:]
            alpha_mean = ca.dot(weights_dm, alpha_i)
            std_term = ca.sqrt(ca.sumsqr(alpha_high_coeffs))

        opti.subject_to(alpha_mean + 3 * std_term <= alphamax)
        opti.subject_to(alpha_mean - 3 * std_term >= -alphamax)
            
    for i in range(N):
        h_ddot_vec = ca.vertcat(*h_ddot_all[i])
        h_ddot_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * h_ddot_vec)
        h_ddot_mean = h_ddot_pce_coeffs[0]
        h_ddot_high_coeffs = h_ddot_pce_coeffs[1:]
        h_ddot_std_term = ca.sqrt(ca.sumsqr(h_ddot_high_coeffs))
        
        opti.subject_to(h_ddot_mean + 3 * h_ddot_std_term <= 10 * g)
        opti.subject_to(h_ddot_mean - 3 * h_ddot_std_term >= -2 * g)


    # # Cost function
    # J = dt * ca.sumsqr((h_s - (hR / hscale))**3)
    opti.minimize(J)

    # Initial guess
    for j in range(M):
        opti.set_initial(x_s[j, :], np.linspace(0, 1, N+1))
        opti.set_initial(h_s[j, :], 0.6)  # 600 ft / 1000
        opti.set_initial(V_s[j, :], 239.7 / Vscale)
        opti.set_initial(gamma_s[j, :], -0.01 / gammascale)
        opti.set_initial(alpha_s[j, :], 0.02 / alphascale)
    opti.set_initial(u_s, 0)

    # Solver
    opts = {
        "expand": True,
        "ipopt": {
            # "max_iter": 3000,
            "max_cpu_time": 120,
            "tol": 1e-6,
            "print_level": 0,
            "linear_solver": "mumps",
            "hessian_approximation": "limited-memory",
            # "bound_push": 1e-8,
            # "bound_frac": 1e-8
        }
    }
    opti.solver("ipopt", opts)

    try:
        sol = opti.solve()
    except RuntimeError as e:
        opti.debug.show_infeasibilities()
        print(e)
        return {
            "x": opti.debug.value(x),
            "h": opti.debug.value(h),
            "V": opti.debug.value(V),
            "gamma": opti.debug.value(gamma),
            "alpha": opti.debug.value(alpha),
            "u": opti.debug.value(u),
            "J": opti.debug.value(J),
            "status": "failed"
        }

    return {
        "x": sol.value(x),
        "h": sol.value(h),
        "V": sol.value(V),
        "gamma": sol.value(gamma),
        "alpha": sol.value(alpha),
        "u": sol.value(u),
        "J": sol.value(J),
        "time_grid": np.linspace(0, tf, N+1),
        "status": "success"
    }

# %%
def solve_wider_wind_ocp_pce_w_adaptive_mesh(pce_order, k_mean, k_std, s_mean, s_std, du_tol=1e-3, max_iter=3):
    
    def refine_time_grid(u_guess, time_grid, du_tol=0.1):
        refined = False
        u_guess = np.asarray(u_guess)
        time_grid = np.asarray(time_grid)
        du = np.abs(np.diff(np.insert(u_guess, 0, u_guess[0])))
        refined_time_grid = [time_grid[0]]  # Start with the first time point
        for i in range(1, len(du)):
            if du[i-1] > du_tol:
                refined = True
                t_mid = (time_grid[i-1] + time_grid[i]) / 2
                refined_time_grid.append(t_mid)
            refined_time_grid.append(time_grid[i])
        refined_time_grid.append(time_grid[-1])  # Ensure the last time point is included
        return refined, np.unique(refined_time_grid)
    
    # Time and discretization
    tf = 50        # final time [sec]
    N = 50         # number of control intervals
    # dt = tf / N    # time step
    time_grid = np.linspace(0, tf, N+1)  # time grid for adaptive mesh

    # Aircraft physical constants
    m = 4662                # mass [lb sec^2 / ft]
    g = 32.172              # gravity [ft/sec^2]
    delta = 0.03491         # thrust inclination angle [rad]

    # Thrust model coefficients: T = A0 + A1*V + A2*V^2
    A0 = 0.4456e5           # [lb]
    A1 = -0.2398e2          # [lb sec / ft]
    A2 = 0.1442e-1          # [lb sec^2 / ft^2]

    # Aerodynamic model
    rho = 0.2203e-2         # air density [lb sec^2 / ft^4]
    S = 0.1560e4            # reference surface area [ft^2]

    # Wind model 3 beta (smoothing) parameters
    beta0 = 0.4             # initial beta value (approximate)
    beta_dot0 = 0.2         # initial beta rate
    sigma = 3               # time to reach beta = 1 [sec]

    # C_D(alpha) = B0 + B1 * alpha + B2 * alpha**2, D = 0.5 * C_D(α) * ρ * S * V²
    B0 = 0.1552
    B1 = 0.12369            # [1/rad]
    B2 = 2.4203             # [1/rad^2]

    # Lift coefficient: C_L = C0 + C1 * alpha (+ C2 * alpha**2)
    C0 = 0.7125             # baseline lift coefficient
    C1 = 6.0877             # AOA lift slope [1/rad]

    # Lift/drag model optional extensions (if needed)
    C2 = -9.0277            # [rad^-2] — e.g., for moment or drag extension

    # Angle of attack & control constraints
    umax = 0.05236          # max control input (rate of change of alpha) [rad/sec]
    alphamax = 0.3          # max angle of attack [rad]
    alpha_star = 0.20944    # changing pt of AoA

    # Wind model x parameters (piecewise smooth wind)
    a = 6e-8                 # x transition midpoint [ft]
    b = -4e-11               # second transition point [ft]

    # Wind model h parameters (polynomial form)
    c = -np.log(25/30.6)*1e-12      # transition smoothing width [ft]
    d = -8.02881e-8         # polynomial coeff [sec^-1 ft^-2]
    e = 6.28083e-11         # polynomial coeff [sec^-1 ft^-3]

    # Cost function / target altitude
    hR = 1000               # reference altitude [ft]
    h_star = 1000           # used in some wind models

    # Auxiliary
    eps = 1e-6              # to avoid division by zero in V

    # Scaling factors (used if normalizing states)
    xscale = 10000          # [ft]
    hscale = 1000           # [ft]
    Vscale = 240            # [ft/sec]
    gammascale = 0.1        # [rad]
    alphascale = 0.3        # [rad]
    uscale = 0.05           # [rad/sec]

    # PCE parameters
    k_dist = cp.Normal(k_mean, k_std)
    s_dist = cp.Normal(s_mean, s_std)
    joint_dist = cp.J(k_dist, s_dist)
    
    poly_basis = cp.expansion.stieltjes(pce_order, joint_dist)
    nodes, weights = cp.generate_quadrature(pce_order, joint_dist, rule='G')
    # print(poly_basis.shape)     # ((pce_order+1)(pce_order+2)/2, )
    # print(weights.shape)        # ((pce_order+1)^2, )
    # print(nodes.shape)          # (2, (pce_order+1)^2)
    
    M = nodes.shape[1]              # number of PCE samples
    
    weights_dm = ca.DM(weights)   # ((pce_order+1)^2， )
    
    Psi_mat = poly_basis(*nodes)    # (M_poly_basis, (pce_order+1)^2)
    Psi_dm = ca.DM(Psi_mat)         # (M_poly_basis, (pce_order+1)^2)

    def Smooth(x_, x0, x1):
        t = (x_ - x0) / (x1 - x0 + eps)
        return ca.if_else(x_ < x0, 0,
               ca.if_else(x_ > x1, 1, 6*t**5 - 15*t**4 + 10*t**3))

    def A_piecewise(x_, s_):
        A1 = -50 + a * (x_/s_)**3 + b * (x_/s_)**4
        A2 = 0.025 * ((x_/s_) - 2300)
        A3 = 50 - a * (4600 - (x_/s_))**3 - b * (4600 - (x_/s_))**4
        A4 = 50
        s1 = Smooth(x_, 480 * s_, 520 * s_)
        s2 = Smooth(x_, 4080 * s_, 4120 * s_)
        s3 = Smooth(x_, 4580 * s_, 4620 * s_)
        B12 = (1 - s1)*A1 + s1*A2
        B23 = (1 - s2)*A2 + s2*A3
        B34 = (1 - s3)*A3 + s3*A4
        return ca.if_else(x_ <= 500 * s_, B12,
               ca.if_else(x_ <= 4100 * s_, B23,
               ca.if_else(x_ <= 4600 * s_, B34, A4)))

    def B_piecewise(x_, s_):
        B1 = d * (x_/s_)**3 + e * (x_/s_)**4
        B2 = -51 * ca.exp(ca.fmin(-c * ((x_/s_) - 2300)**4, 30))
        B3 = d * (4600 - (x_/s_))**3 + e * (4600 - (x_/s_))**4
        B4 = 0
        s1 = Smooth(x_, 480 * s_, 520 * s_)
        s2 = Smooth(x_, 4080 * s_, 4120 * s_)
        s3 = Smooth(x_, 4580 * s_, 4620 * s_)
        B12 = (1 - s1)*B1 + s1*B2
        B23 = (1 - s2)*B2 + s2*B3
        B34 = (1 - s3)*B3 + s3*B4
        return ca.if_else(x_ <= 500 * s_, B12,
               ca.if_else(x_ <= 4100 * s_, B23,
               ca.if_else(x_ <= 4600 * s_, B34, B4)))

    def wind_x(x_, k_, s_):
        return k_ * A_piecewise(x_, s_)

    def wind_h(x_, h_, k_, s_):
        h_safe = ca.fmax(h_, 10.0)
        return k_ * h_safe / h_star * B_piecewise(x_, s_)

    def C_L(alpha_):
        return ca.if_else(alpha_ > alpha_star, C0 + C1 * alpha_,
                          C0 + C1 * alpha_ + C2 * (alpha_ - alpha_star)**2)
    def beta(t_):
        return ca.if_else(t_ < sigma, beta0 + beta_dot0 * t_, 1.0)

    def rk4_step(f, xk, uk, tk, dt, k_val, s_val):
        k1 = f(xk, uk, tk, k_val, s_val)
        k2 = f(xk + dt/2 * k1, uk, tk + dt/2, k_val, s_val)
        k3 = f(xk + dt/2 * k2, uk, tk + dt/2, k_val, s_val)
        k4 = f(xk + dt * k3, uk, tk + dt, k_val, s_val)
        return xk + dt/6 * (k1 + 2*k2 + 2*k3 + k4)
    
    def solve_ocp(time_grid):
        N = len(time_grid)
        dt_list = np.diff(time_grid)  # Calculate time steps from the time grid
        
        # Opti instance and scaled variables
        opti = ca.Opti()
        x_s = opti.variable(M, N+1)
        h_s = opti.variable(M, N+1)
        V_s = opti.variable(M, N+1)
        gamma_s = opti.variable(M, N+1)
        alpha_s = opti.variable(M, N+1)
        X_pce = opti.variable(5*(pce_order+1), N+1)
        u_s = opti.variable(N)

        # Unscaled variables for dynamics
        x = x_s * xscale
        h = h_s * hscale
        V = V_s * Vscale
        gamma = gamma_s * gammascale
        alpha = alpha_s * alphascale
        u = u_s * uscale

        # Symbolic derivatives
        x_sym = ca.MX.sym("x")
        h_sym = ca.MX.sym("h")
        k_sym = ca.MX.sym("k")
        s_sym = ca.MX.sym("s")
        Wx_expr = wind_x(x_sym, k_sym, s_sym)
        Wh_expr = wind_h(x_sym, h_sym, k_sym, s_sym)
        dWx_dx_fun = ca.Function("dWx_dx", [x_sym, k_sym, s_sym], [ca.gradient(Wx_expr, x_sym)])
        dWh_dx_fun = ca.Function("dWh_dx", [x_sym, h_sym, k_sym, s_sym], [ca.gradient(Wh_expr, x_sym)])
        dWh_dh_fun = ca.Function("dWh_dh", [x_sym, h_sym, k_sym, s_sym], [ca.gradient(Wh_expr, h_sym)])
        
        def aircraft_ode(X, u_, t_, k_val, s_val):
            x_, h_, V_, gamma_, alpha_ = ca.vertsplit(X)

            T = beta(t_) * (A0 + A1 * V_ + A2 * V_**2)
            D = 0.5 * (B0 + B1 * alpha_ + B2 * alpha_**2) * rho * S * V_**2
            L = 0.5 * rho * S * C_L(alpha_) * V_**2

            Wx = wind_x(x_, k_val, s_val)
            Wh = wind_h(x_, h_, k_val, s_val)
            V_safe = ca.fmax(V_, 1e-3)

            x_dot = V_ * ca.cos(gamma_) + Wx
            h_dot = V_ * ca.sin(gamma_) + Wh

            dWx_dx_val = dWx_dx_fun(x_, k_val, s_val)[0]
            dWh_dx_val = dWh_dx_fun(x_, h_, k_val, s_val)[0]
            dWh_dh_val = dWh_dh_fun(x_, h_, k_val, s_val)[0]

            Wx_dot = dWx_dx_val * x_dot
            Wh_dot = dWh_dx_val * x_dot + dWh_dh_val * h_dot

            V_dot = T / m * ca.cos(alpha_ + delta) - D / m - g * ca.sin(gamma_) - (Wx_dot * ca.cos(gamma_) + Wh_dot * ca.sin(gamma_))
            gamma_dot = T / (m * V_safe) * ca.sin(alpha_ + delta) + L / (m * V_safe) - g / V_safe * ca.cos(gamma_) + (1 / V_safe) * (Wx_dot * ca.sin(gamma_) - Wh_dot * ca.cos(gamma_))
            alpha_dot = u_

            return ca.vertcat(x_dot, h_dot, V_dot, gamma_dot, alpha_dot)

        J = 0

        # Initial conditions
        opti.subject_to(x_s[:, 0] == 0)
        opti.subject_to(h_s[:, 0] == 600 / hscale)
        opti.subject_to(V_s[:, 0] == 239.7 / Vscale)
        opti.subject_to(gamma_s[:, 0] == -0.03925 / gammascale)
        opti.subject_to(alpha_s[:, 0] == 0.1283 / alphascale)
        opti.subject_to(ca.vec(V_s) >= 1e-2 / Vscale)
        # opti.subject_to(gamma_s[:, -1] == -0.05236 / gammascale)
        opti.subject_to(gamma_s[:, -1] >= 0)
        
        h_ddot_all = [[] for _ in range(N)]
        
        for j in range(M):
            k_val, s_val = nodes[:, j]
            
            i = 0
            dt = 0
            tk = time_grid[i]  # Current time from the time grid
                
            h_physical = h_s[:, i] * hscale
            h_mean = ca.dot(weights_dm, h_physical)

            h_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * h_physical)
            h_high_coeffs = h_pce_coeffs[1:]
            h_std_term = ca.sqrt(ca.sumsqr(h_high_coeffs))

            deviation = hR - h_mean + h_std_term * 12
            scaled_deviation = deviation / hscale
            J += dt * scaled_deviation**6

            Xk = ca.vertcat(x[j, i], h[j, i], V[j, i], gamma[j, i], alpha[j, i])
            Uk = u[i]
            
            # h_ddot = d^2h/dt^2 = V_dot * sin(gamma) + V * cos(gamma) * gamma_dot + Wh_dot
            ode_out = aircraft_ode(Xk, Uk, tk, k_val, s_val)
            x_dot_k = ode_out[0]
            h_dot_k = ode_out[1]
            V_dot_k = ode_out[2]
            gamma_dot_k = ode_out[3]
            # alpha_dot_k = ode_out[4]
            
            dWh_dx_val = dWh_dx_fun(Xk[0], Xk[1], k_val, s_val)[0]
            dWh_dh_val = dWh_dh_fun(Xk[0], Xk[1], k_val, s_val)[0]
            Wh_dot_k = dWh_dx_val * x_dot_k + dWh_dh_val * h_dot_k
            
            h_ddot_k = V_dot_k * ca.sin(Xk[3]) + Xk[2] * ca.cos(Xk[3]) * gamma_dot_k + Wh_dot_k
            
            h_ddot_all[i].append(h_ddot_k)
            
            Xk_end = rk4_step(aircraft_ode, Xk, Uk, tk, dt, k_val, s_val)
            X_next = ca.vertcat(x[j, i+1], h[j, i+1], V[j, i+1], gamma[j, i+1], alpha[j, i+1])
            opti.subject_to(X_next == Xk_end)

            opti.subject_to(opti.bounded(-1, u_s[i], 1))

            alpha_i = alpha_s[:, i] * alphascale
            alpha_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * alpha_i)
            alpha_high_coeffs = alpha_pce_coeffs[1:]
            alpha_mean = ca.dot(weights_dm, alpha_i)
            std_term = ca.sqrt(ca.sumsqr(alpha_high_coeffs))
            
            for i in range(1, N):
                dt = dt_list[i-1]  # Use the time step from the time grid
                tk = time_grid[i]  # Current time from the time grid
                
                h_physical = h_s[:, i] * hscale
                h_mean = ca.dot(weights_dm, h_physical)

                h_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * h_physical)
                h_high_coeffs = h_pce_coeffs[1:]
                h_std_term = ca.sqrt(ca.sumsqr(h_high_coeffs))

                deviation = hR - h_mean + h_std_term * 12
                scaled_deviation = deviation / hscale
                J += dt * scaled_deviation**6

                Xk = ca.vertcat(x[j, i], h[j, i], V[j, i], gamma[j, i], alpha[j, i])
                Uk = u[i]
                
                # h_ddot = d^2h/dt^2 = V_dot * sin(gamma) + V * cos(gamma) * gamma_dot + Wh_dot
                ode_out = aircraft_ode(Xk, Uk, tk, k_val, s_val)
                x_dot_k = ode_out[0]
                h_dot_k = ode_out[1]
                V_dot_k = ode_out[2]
                gamma_dot_k = ode_out[3]
                # alpha_dot_k = ode_out[4]
                
                dWh_dx_val = dWh_dx_fun(Xk[0], Xk[1], k_val, s_val)[0]
                dWh_dh_val = dWh_dh_fun(Xk[0], Xk[1], k_val, s_val)[0]
                Wh_dot_k = dWh_dx_val * x_dot_k + dWh_dh_val * h_dot_k
                
                h_ddot_k = V_dot_k * ca.sin(Xk[3]) + Xk[2] * ca.cos(Xk[3]) * gamma_dot_k + Wh_dot_k
                
                h_ddot_all[i].append(h_ddot_k)
                
                Xk_end = rk4_step(aircraft_ode, Xk, Uk, tk, dt, k_val, s_val)
                X_next = ca.vertcat(x[j, i+1], h[j, i+1], V[j, i+1], gamma[j, i+1], alpha[j, i+1])
                opti.subject_to(X_next == Xk_end)

                opti.subject_to(opti.bounded(-1, u_s[i], 1))

                alpha_i = alpha_s[:, i] * alphascale
                alpha_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * alpha_i)
                alpha_high_coeffs = alpha_pce_coeffs[1:]
                alpha_mean = ca.dot(weights_dm, alpha_i)
                std_term = ca.sqrt(ca.sumsqr(alpha_high_coeffs))

            opti.subject_to(alpha_mean + 3 * std_term <= alphamax)
            opti.subject_to(alpha_mean - 3 * std_term >= -alphamax)
                
        for i in range(N):
            h_ddot_vec = ca.vertcat(*h_ddot_all[i])
            h_ddot_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * h_ddot_vec)
            h_ddot_mean = h_ddot_pce_coeffs[0]
            h_ddot_high_coeffs = h_ddot_pce_coeffs[1:]
            h_ddot_std_term = ca.sqrt(ca.sumsqr(h_ddot_high_coeffs))
            
            opti.subject_to(h_ddot_mean + 3 * h_ddot_std_term <= 10 * g)
            opti.subject_to(h_ddot_mean - 3 * h_ddot_std_term >= -2 * g)

        opti.minimize(J)

        # Initial guess
        for j in range(M):
            opti.set_initial(x_s[j, :], np.linspace(0, 1, N+1))
            opti.set_initial(h_s[j, :], 0.6)  # 600 ft / 1000
            opti.set_initial(V_s[j, :], 239.7 / Vscale)
            opti.set_initial(gamma_s[j, :], -0.01 / gammascale)
            opti.set_initial(alpha_s[j, :], 0.02 / alphascale)
        opti.set_initial(u_s, 0)

        # Solver
        opts = {
            "expand": True,
            "ipopt": {
                # "max_iter": 3000,
                "max_cpu_time": 120,
                "tol": 1e-6,
                "print_level": 0,
                "linear_solver": "mumps",
                "hessian_approximation": "limited-memory",
                # "bound_push": 1e-8,
                # "bound_frac": 1e-8
            }
        }
        opti.solver("ipopt", opts)

        try:
            sol = opti.solve()
        except RuntimeError as e:
            opti.debug.show_infeasibilities()
            print(e)
            return {
                "x": opti.debug.value(x),
                "h": opti.debug.value(h),
                "V": opti.debug.value(V),
                "gamma": opti.debug.value(gamma),
                "alpha": opti.debug.value(alpha),
                "u": opti.debug.value(u),
                "J": opti.debug.value(J),
                "time_grid": time_grid,
                "dt_list": dt_list,
                "status": "failed"
            }

        return {
            "x": sol.value(x),
            "h": sol.value(h),
            "V": sol.value(V),
            "gamma": sol.value(gamma),
            "alpha": sol.value(alpha),
            "u": sol.value(u),
            "J": sol.value(J),
            "time_grid": time_grid,
            "dt_list": dt_list,
            "status": "success"
        }

    def solve_and_refine(time_grid, max_iter=3):
        refined = True
        iter_count = 0
        while refined and iter_count < max_iter:
            sol = solve_ocp(time_grid)
            
            # Check if further refinement is needed
            refined, new_time_grid = refine_time_grid(sol["u"], time_grid, du_tol)
            if refined:
                time_grid = new_time_grid
                iter_count += 1
                print(f"Refining time grid, iteration {iter_count}")
            else:
                break
    
        return sol
    
    return solve_and_refine(time_grid, max_iter=max_iter)

# %%
res = solve_wider_wind_ocp_pce_w_adaptive_mesh(pce_order=2, k_mean=1.0, k_std=0.08, s_mean=1.0, s_std=0.15, max_iter=3)
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.84ms (105.20us)   4.92ms (106.89us)        46
#        nlp_g  | 229.22ms (  4.98ms) 230.95ms (  5.02ms)        46
#   nlp_grad_f  |   8.42ms (191.45us)   8.28ms (188.27us)        44
#    nlp_jac_g  |   1.05 s ( 23.95ms)   1.06 s ( 24.14ms)        44
#        total  |   2.27 s (  2.27 s)   2.31 s (  2.31 s)         1
# Refining time grid, iteration 1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   8.69ms (184.83us)   8.71ms (185.26us)        47
#        nlp_g  | 433.53ms (  9.22ms) 436.99ms (  9.30ms)        47
#   nlp_grad_f  |  16.94ms (352.96us)  16.95ms (353.17us)        48
#    nlp_jac_g  |   2.08 s ( 43.42ms)   2.09 s ( 43.44ms)        48
#        total  |   4.45 s (  4.45 s)   4.46 s (  4.46 s)         1
# Refining time grid, iteration 2
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  19.04ms (312.18us)  19.07ms (312.59us)        61
#        nlp_g  | 948.28ms ( 15.55ms) 948.41ms ( 15.55ms)        61
#   nlp_grad_f  |  35.71ms (595.17us)  35.71ms (595.12us)        60
#    nlp_jac_g  |   4.57 s ( 76.16ms)   4.57 s ( 76.20ms)        60
#        total  |   9.68 s (  9.68 s)   9.69 s (  9.69 s)         1
# Refining time grid, iteration 3

# %%
time_grid = res["time_grid"]
u = res["u"]  # shape: (N,)

plt.figure(figsize=(18, 5))
plt.step(time_grid, u, label='Optimal u', linewidth=2)
plt.plot(time_grid, -0.06*np.ones_like(time_grid), 'r.', label='Time Grid Points')
plt.xlabel('Time [s]')
plt.ylabel('u (control)')
plt.title('Adaptive Control $u$ on Adaptive Mesh')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
res_no_sc = solve_wider_wind_ocp_pce(tf = 50, N = 100, pce_order=2, k_mean=1.0, k_std=0.08, s_mean=1.0, s_std=0.15)
# Out:
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  10.21ms (200.14us)  10.22ms (200.32us)        51
#        nlp_g  | 489.57ms (  9.60ms) 489.85ms (  9.60ms)        51
#   nlp_grad_f  |  18.90ms (370.63us)  18.88ms (370.16us)        51
#    nlp_jac_g  |   2.41 s ( 47.18ms)   2.49 s ( 48.78ms)        51
#        total  |   5.00 s (  5.00 s)   5.08 s (  5.08 s)         1

# %%
plt.figure(figsize=(18, 5))
plt.step(res["time_grid"], res["u"], label='Optimal u with step control', linewidth=2)
plt.plot(res["time_grid"], -0.06*np.ones_like(res["time_grid"]), '.', color='tab:blue', label='Time Grid Points')
plt.step(res_no_sc["time_grid"][1:], res_no_sc["u"], label='Optimal u without step control', linewidth=2)
plt.plot(res_no_sc["time_grid"], -0.063*np.ones_like(res_no_sc["time_grid"]), '.', color='tab:orange', label='Time Grid Points without step control')
plt.xlabel('Time [s]')
plt.ylabel('u (control)')
plt.title('Optimal Control $u$')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
colors = {
    "safe": "#2c7bb6",      # Dark Blue
    "low": "#abd9e9",       # Light Blue
    "very_low": "#fdae61",  # Orange
    "crash": "#d7191c"      # Red
}

# Physical constants
m = 4662
g = 32.172
delta = 0.03491
A0 = 0.4456e5
A1 = -0.2398e2
A2 = 0.1442e-1
rho = 0.2203e-2
S = 0.1560e4
beta0 = 0.4
beta_dot0 = 0.2
sigma = 3
B0 = 0.1552
B1 = 0.12369
B2 = 2.4203
C0 = 0.7125
C1 = 6.0877
C2 = -9.0277
alpha_star = 0.20944
a = 6e-8
b = -4e-11
c = -np.log(25/30.6)*1e-12
d = -8.02881e-8
e = 6.28083e-11
h_star = 1000
eps = 1e-6

# Wind model functions
def Smooth(x_, x0, x1):
    t = (x_ - x0) / (x1 - x0 + eps)
    return ca.if_else(x_ < x0, 0,
           ca.if_else(x_ > x1, 1, 6*t**5 - 15*t**4 + 10*t**3))

def A_piecewise(x_, s_):
    A1 = -50 + a * (x_/s_)**3 + b * (x_/s_)**4
    A2 = 0.025 * ((x_/s_) - 2300)
    A3 = 50 - a * (4600 - (x_/s_))**3 - b * (4600 - (x_/s_))**4
    A4 = 50
    s1 = Smooth(x_, 480 * s_, 520 * s_)
    s2 = Smooth(x_, 4080 * s_, 4120 * s_)
    s3 = Smooth(x_, 4580 * s_, 4620 * s_)
    B12 = (1 - s1)*A1 + s1*A2
    B23 = (1 - s2)*A2 + s2*A3
    B34 = (1 - s3)*A3 + s3*A4
    return ca.if_else(x_ <= 500 * s_, B12,
            ca.if_else(x_ <= 4100 * s_, B23,
            ca.if_else(x_ <= 4600 * s_, B34, A4)))

def B_piecewise(x_, s_):
    B1 = d * (x_/s_)**3 + e * (x_/s_)**4
    B2 = -51 * ca.exp(ca.fmin(-c * ((x_/s_) - 2300)**4, 30))
    B3 = d * (4600 - (x_/s_))**3 + e * (4600 - (x_/s_))**4
    B4 = 0
    s1 = Smooth(x_, 480 * s_, 520 * s_)
    s2 = Smooth(x_, 4080 * s_, 4120 * s_)
    s3 = Smooth(x_, 4580 * s_, 4620 * s_)
    B12 = (1 - s1)*B1 + s1*B2
    B23 = (1 - s2)*B2 + s2*B3
    B34 = (1 - s3)*B3 + s3*B4
    return ca.if_else(x_ <= 500 * s_, B12,
            ca.if_else(x_ <= 4100 * s_, B23,
            ca.if_else(x_ <= 4600 * s_, B34, B4)))

def wind_x(x_, k_, s_):
    return k_ * A_piecewise(x_, s_)

def wind_h(x_, h_, k_, s_):
    h_safe = ca.fmax(h_, 10.0)
    return k_ * h_safe / h_star * B_piecewise(x_, s_)

def originalWindModel(x_, h_, k_, s_):
    return wind_x(x_, k_, s_), wind_h(x_, h_, k_, s_)

def C_L(alpha_):
    return ca.if_else(alpha_ > alpha_star, C0 + C1 * alpha_,
                      C0 + C1 * alpha_ + C2 * (alpha_ - alpha_star)**2)
def beta(t_):
    return ca.if_else(t_ < sigma, beta0 + beta_dot0 * t_, 1.0)

def aircraft_ode(k_value):
    s_value = (1.0 / k_value) ** 2
    x_ = ca.MX.sym('x')
    h_ = ca.MX.sym('h')
    V_ = ca.MX.sym('V')
    gamma_ = ca.MX.sym('gamma')
    alpha_ = ca.MX.sym('alpha')

    u_ = ca.MX.sym('u')
    t_ = ca.MX.sym('t')

    T = beta(t_) * (A0 + A1 * V_ + A2 * V_**2)
    D = 0.5 * (B0 + B1 * alpha_ + B2 * alpha_**2) * rho * S * V_**2
    L = 0.5 * rho * S * C_L(alpha_) * V_**2

    Wx, Wh = originalWindModel(x_, h_, k_value, s_value)
    dWx_dx_fun = ca.Function("dWx_dx", [x_], [ca.gradient(Wx, x_)])
    dWh_dx_fun = ca.Function("dWh_dx", [x_, h_], [ca.gradient(Wh, x_)])
    dWh_dh_fun = ca.Function("dWh_dh", [x_, h_], [ca.gradient(Wh, h_)])

    V_safe = ca.fmax(V_, 1e-3)

    x_dot = V_ * ca.cos(gamma_) + Wx
    h_dot = V_ * ca.sin(gamma_) + Wh

    dWx_dx_val = dWx_dx_fun(x_)[0]
    dWh_dx_val = dWh_dx_fun(x_, h_)[0]
    dWh_dh_val = dWh_dh_fun(x_, h_)[0]

    Wx_dot = dWx_dx_val * x_dot
    Wh_dot = dWh_dx_val * x_dot + dWh_dh_val * h_dot

    V_dot = (
        T / m * ca.cos(alpha_ + delta)
        - D / m
        - g * ca.sin(gamma_)
        - (Wx_dot * ca.cos(gamma_) + Wh_dot * ca.sin(gamma_))
    )
    gamma_dot = (
        T / (m * V_safe) * ca.sin(alpha_ + delta)
        + L / (m * V_safe)
        - g / V_safe * ca.cos(gamma_)
        + (1 / V_safe) * (Wx_dot * ca.sin(gamma_) - Wh_dot * ca.cos(gamma_))
    )
    alpha_dot = u_

    y0 = ca.vertcat(x_, h_, V_, gamma_, alpha_)
    yk = ca.vertcat(x_dot, h_dot, V_dot, gamma_dot, alpha_dot)
    return ca.Function('f', [y0, u_, t_], [yk])

def rk4_step(f, xk, uk, tk, dt):
    k1 = f(xk, uk, tk)
    k2 = f(xk + dt/2 * k1, uk, tk + dt/2)
    k3 = f(xk + dt/2 * k2, uk, tk + dt/2)
    k4 = f(xk + dt * k3, uk, tk + dt)
    return xk + dt/6 * (k1 + 2*k2 + 2*k3 + k4)

def reconstruct_trajectory(u_opt, time_grid, k, x0=0, h0=600, V0=239.7, gamma0=-0.03925, alpha0=0.1283):
    traj = {"x": [], "h": [], "V": [], "gamma": [], "alpha": [], "t": []}
    X = np.array([x0, h0, V0, gamma0, alpha0])

    f = aircraft_ode(k)

    dt_ls = np.diff(time_grid)
    for i, u in enumerate(u_opt):
        t = time_grid[i]
        dt = dt_ls[i]
        traj["x"].append(float(X[0]))
        traj["h"].append(float(X[1]))
        traj["V"].append(float(X[2]))
        traj["gamma"].append(float(X[3]))
        traj["alpha"].append(float(X[4]))
        traj["t"].append(t)
        X = rk4_step(f, X, u, t, dt)

    traj["x"].append(float(X[0]))
    traj["h"].append(float(X[1]))
    traj["V"].append(float(X[2]))
    traj["gamma"].append(float(X[3]))
    traj["alpha"].append(float(X[4]))
    traj["t"].append(t + dt)
    return traj

def visualize_trajectory(u_opt, time_grid):
    k_values = np.random.normal(1.0, 0.08, 10000)

    under_0, under_50, under_100 = 0, 0, 0

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

    for k in k_values:
        traj = reconstruct_trajectory(u_opt, time_grid, k)

        if min(traj["h"]) < 1e-6:
            under_0 += 1
            print(k)
            ax1.plot(traj["x"], traj["h"], alpha=0.3, color=colors["crash"])
            ax2.plot(time_grid, traj["V"], alpha=0.3, color=colors["crash"])
        elif min(traj["h"]) < 50:
            under_50 += 1
            ax1.plot(traj["x"], traj["h"], alpha=0.3, color=colors["very_low"])
            ax2.plot(time_grid, traj["V"], alpha=0.3, color=colors["very_low"])
        elif min(traj["h"]) < 100:
            under_100 += 1
            ax1.plot(traj["x"], traj["h"], alpha=0.3, color=colors["low"])
            ax2.plot(time_grid, traj["V"], alpha=0.3, color=colors["low"])
        else:
            ax1.plot(traj["x"], traj["h"], alpha=0.3, color=colors["safe"])
            ax2.plot(time_grid, traj["V"], alpha=0.3, color=colors["safe"])

    ax1.set_xlabel("x [ft]")
    ax1.set_ylabel("h [ft]")
    ax1.set_title("Trajectory (x vs h)")
    ax1.grid(True)
    legend_elements = [
        Line2D([0], [0], color=colors["safe"],      lw=2, label='Safe (h ≥ 100 ft)'),
        Line2D([0], [0], color=colors["low"],       lw=2, label='Low (50 ≤ h < 100 ft)'),
        Line2D([0], [0], color=colors["very_low"],  lw=2, label='Very low (0 ≤ h < 50 ft)'),
        Line2D([0], [0], color=colors["crash"],     lw=2, label='Crash (h ≤ 0)')
    ]
    ax1.legend(handles=legend_elements, loc='upper left', title="Min Altitude Zones")

    ax2.set_xlabel("t [sec]")
    ax2.set_ylabel("V [ft/s]")
    ax2.set_title("Velocity (V vs x)")
    ax2.grid(True)
    # ax2.legend()

    plt.tight_layout()
    plt.show()

    print(f"P(Under 100) = {(under_100+under_50+under_0)/len(k_values):.4f}")
    print(f"P(Under 50) = {(under_50+under_0)/len(k_values):.4f}")
    print(f"P(Under 0) = {under_0/len(k_values):.4f}")

# %%
visualize_trajectory(res["u"][1:], res["time_grid"])
# Out:
# 1.2830738033621005
# 1.2912641512374339
# 1.296741829854981
# 1.2882121257040746
# 1.2936380484839218
# 1.306971738675763
# P(Under 100) = 0.0038
# P(Under 50) = 0.0013
# P(Under 0) = 0.0006

# %%
visualize_trajectory(res_no_sc["u"], res_no_sc["time_grid"])
# Out:
# 1.285664618510668
# 1.3553896852839529
# 1.2852273654789597
# P(Under 100) = 0.0028
# P(Under 50) = 0.0011
# P(Under 0) = 0.0003

# %%
def solve_wider_wind_ocp_pce_w_adaptive_mesh_q(pce_order, k_mean, k_std, du_tol=1e-3, max_iter=3):
    
    def refine_time_grid(u_guess, time_grid, du_tol=0.1):
        refined = False
        u_guess = np.asarray(u_guess)
        time_grid = np.asarray(time_grid)
        du = np.abs(np.diff(np.insert(u_guess, 0, u_guess[0])))
        refined_time_grid = [time_grid[0]]  # Start with the first time point
        for i in range(1, len(du)):
            if du[i-1] > du_tol:
                refined = True
                t_mid = (time_grid[i-1] + time_grid[i]) / 2
                refined_time_grid.append(t_mid)
            refined_time_grid.append(time_grid[i])
        refined_time_grid.append(time_grid[-1])  # Ensure the last time point is included
        return refined, np.unique(refined_time_grid)
    
    # Time and discretization
    tf = 50        # final time [sec]
    N = 50         # number of control intervals
    # dt = tf / N    # time step
    time_grid = np.linspace(0, tf, N+1)  # time grid for adaptive mesh

    # Aircraft physical constants
    m = 4662                # mass [lb sec^2 / ft]
    g = 32.172              # gravity [ft/sec^2]
    delta = 0.03491         # thrust inclination angle [rad]

    # Thrust model coefficients: T = A0 + A1*V + A2*V^2
    A0 = 0.4456e5           # [lb]
    A1 = -0.2398e2          # [lb sec / ft]
    A2 = 0.1442e-1          # [lb sec^2 / ft^2]

    # Aerodynamic model
    rho = 0.2203e-2         # air density [lb sec^2 / ft^4]
    S = 0.1560e4            # reference surface area [ft^2]

    # Wind model 3 beta (smoothing) parameters
    beta0 = 0.4             # initial beta value (approximate)
    beta_dot0 = 0.2         # initial beta rate
    sigma = 3               # time to reach beta = 1 [sec]

    # C_D(alpha) = B0 + B1 * alpha + B2 * alpha**2, D = 0.5 * C_D(α) * ρ * S * V²
    B0 = 0.1552
    B1 = 0.12369            # [1/rad]
    B2 = 2.4203             # [1/rad^2]

    # Lift coefficient: C_L = C0 + C1 * alpha (+ C2 * alpha**2)
    C0 = 0.7125             # baseline lift coefficient
    C1 = 6.0877             # AOA lift slope [1/rad]

    # Lift/drag model optional extensions (if needed)
    C2 = -9.0277            # [rad^-2] — e.g., for moment or drag extension

    # Angle of attack & control constraints
    umax = 0.05236          # max control input (rate of change of alpha) [rad/sec]
    alphamax = 0.3          # max angle of attack [rad]
    alpha_star = 0.20944    # changing pt of AoA

    # Wind model x parameters (piecewise smooth wind)
    a = 6e-8                 # x transition midpoint [ft]
    b = -4e-11               # second transition point [ft]

    # Wind model h parameters (polynomial form)
    c = -np.log(25/30.6)*1e-12      # transition smoothing width [ft]
    d = -8.02881e-8         # polynomial coeff [sec^-1 ft^-2]
    e = 6.28083e-11         # polynomial coeff [sec^-1 ft^-3]

    # Cost function / target altitude
    hR = 1000               # reference altitude [ft]
    h_star = 1000           # used in some wind models

    # Auxiliary
    eps = 1e-6              # to avoid division by zero in V

    # Scaling factors (used if normalizing states)
    xscale = 10000          # [ft]
    hscale = 1000           # [ft]
    Vscale = 240            # [ft/sec]
    gammascale = 0.1        # [rad]
    alphascale = 0.3        # [rad]
    uscale = 0.05           # [rad/sec]

    # PCE parameters
    k_dist = cp.Normal(k_mean, k_std)
    s_dist = cp.Normal(0.0, 1.0)
    joint_dist = cp.J(k_dist, s_dist)
    
    poly_basis = cp.expansion.stieltjes(pce_order, joint_dist)
    nodes, weights = cp.generate_quadrature(pce_order, joint_dist, rule='G')
    # print(poly_basis.shape)     # ((pce_order+1)(pce_order+2)/2, )
    # print(weights.shape)        # ((pce_order+1)^2, )
    # print(nodes.shape)          # (2, (pce_order+1)^2)
    
    M = nodes.shape[1]              # number of PCE samples
    
    weights_dm = ca.DM(weights)   # ((pce_order+1)^2， )
    
    Psi_mat = poly_basis(*nodes)    # (M_poly_basis, (pce_order+1)^2)
    Psi_dm = ca.DM(Psi_mat)         # (M_poly_basis, (pce_order+1)^2)

    def Smooth(x_, x0, x1):
        t = (x_ - x0) / (x1 - x0 + eps)
        return ca.if_else(x_ < x0, 0,
               ca.if_else(x_ > x1, 1, 6*t**5 - 15*t**4 + 10*t**3))

    def A_piecewise(x_, s_):
        s_ = 1 / (1 - 0.1*s_ + 0.01*s_**2)  # scale factor for s_
        
        A1 = -50 + a * (x_/s_)**3 + b * (x_/s_)**4
        A2 = 0.025 * ((x_/s_) - 2300)
        A3 = 50 - a * (4600 - (x_/s_))**3 - b * (4600 - (x_/s_))**4
        A4 = 50
        s1 = Smooth(x_, 480 * s_, 520 * s_)
        s2 = Smooth(x_, 4080 * s_, 4120 * s_)
        s3 = Smooth(x_, 4580 * s_, 4620 * s_)
        B12 = (1 - s1)*A1 + s1*A2
        B23 = (1 - s2)*A2 + s2*A3
        B34 = (1 - s3)*A3 + s3*A4
        return ca.if_else(x_ <= 500 * s_, B12,
               ca.if_else(x_ <= 4100 * s_, B23,
               ca.if_else(x_ <= 4600 * s_, B34, A4)))

    def B_piecewise(x_, s_):
        s_ = 1 / (1 - 0.1*s_ + 0.01*s_**2)  # scale factor for s_
        
        B1 = d * (x_/s_)**3 + e * (x_/s_)**4
        B2 = -51 * ca.exp(ca.fmin(-c * ((x_/s_) - 2300)**4, 30))
        B3 = d * (4600 - (x_/s_))**3 + e * (4600 - (x_/s_))**4
        B4 = 0
        s1 = Smooth(x_, 480 * s_, 520 * s_)
        s2 = Smooth(x_, 4080 * s_, 4120 * s_)
        s3 = Smooth(x_, 4580 * s_, 4620 * s_)
        B12 = (1 - s1)*B1 + s1*B2
        B23 = (1 - s2)*B2 + s2*B3
        B34 = (1 - s3)*B3 + s3*B4
        return ca.if_else(x_ <= 500 * s_, B12,
               ca.if_else(x_ <= 4100 * s_, B23,
               ca.if_else(x_ <= 4600 * s_, B34, B4)))

    def wind_x(x_, k_, s_):
        return k_ * A_piecewise(x_, s_)

    def wind_h(x_, h_, k_, s_):
        h_safe = ca.fmax(h_, 10.0)
        return k_ * h_safe / h_star * B_piecewise(x_, s_)

    def C_L(alpha_):
        return ca.if_else(alpha_ > alpha_star, C0 + C1 * alpha_,
                          C0 + C1 * alpha_ + C2 * (alpha_ - alpha_star)**2)
    def beta(t_):
        return ca.if_else(t_ < sigma, beta0 + beta_dot0 * t_, 1.0)

    def rk4_step(f, xk, uk, tk, dt, k_val, s_val):
        k1 = f(xk, uk, tk, k_val, s_val)
        k2 = f(xk + dt/2 * k1, uk, tk + dt/2, k_val, s_val)
        k3 = f(xk + dt/2 * k2, uk, tk + dt/2, k_val, s_val)
        k4 = f(xk + dt * k3, uk, tk + dt, k_val, s_val)
        return xk + dt/6 * (k1 + 2*k2 + 2*k3 + k4)
    
    def solve_ocp(time_grid):
        N = len(time_grid)
        dt_list = np.diff(time_grid)  # Calculate time steps from the time grid
        
        # Opti instance and scaled variables
        opti = ca.Opti()
        x_s = opti.variable(M, N+1)
        h_s = opti.variable(M, N+1)
        V_s = opti.variable(M, N+1)
        gamma_s = opti.variable(M, N+1)
        alpha_s = opti.variable(M, N+1)
        X_pce = opti.variable(5*(pce_order+1), N+1)
        u_s = opti.variable(N)

        # Unscaled variables for dynamics
        x = x_s * xscale
        h = h_s * hscale
        V = V_s * Vscale
        gamma = gamma_s * gammascale
        alpha = alpha_s * alphascale
        u = u_s * uscale

        # Symbolic derivatives
        x_sym = ca.MX.sym("x")
        h_sym = ca.MX.sym("h")
        k_sym = ca.MX.sym("k")
        s_sym = ca.MX.sym("s")
        Wx_expr = wind_x(x_sym, k_sym, s_sym)
        Wh_expr = wind_h(x_sym, h_sym, k_sym, s_sym)
        dWx_dx_fun = ca.Function("dWx_dx", [x_sym, k_sym, s_sym], [ca.gradient(Wx_expr, x_sym)])
        dWh_dx_fun = ca.Function("dWh_dx", [x_sym, h_sym, k_sym, s_sym], [ca.gradient(Wh_expr, x_sym)])
        dWh_dh_fun = ca.Function("dWh_dh", [x_sym, h_sym, k_sym, s_sym], [ca.gradient(Wh_expr, h_sym)])
        
        def aircraft_ode(X, u_, t_, k_val, s_val):
            x_, h_, V_, gamma_, alpha_ = ca.vertsplit(X)

            T = beta(t_) * (A0 + A1 * V_ + A2 * V_**2)
            D = 0.5 * (B0 + B1 * alpha_ + B2 * alpha_**2) * rho * S * V_**2
            L = 0.5 * rho * S * C_L(alpha_) * V_**2

            Wx = wind_x(x_, k_val, s_val)
            Wh = wind_h(x_, h_, k_val, s_val)
            V_safe = ca.fmax(V_, 1e-3)

            x_dot = V_ * ca.cos(gamma_) + Wx
            h_dot = V_ * ca.sin(gamma_) + Wh

            dWx_dx_val = dWx_dx_fun(x_, k_val, s_val)[0]
            dWh_dx_val = dWh_dx_fun(x_, h_, k_val, s_val)[0]
            dWh_dh_val = dWh_dh_fun(x_, h_, k_val, s_val)[0]

            Wx_dot = dWx_dx_val * x_dot
            Wh_dot = dWh_dx_val * x_dot + dWh_dh_val * h_dot

            V_dot = T / m * ca.cos(alpha_ + delta) - D / m - g * ca.sin(gamma_) - (Wx_dot * ca.cos(gamma_) + Wh_dot * ca.sin(gamma_))
            gamma_dot = T / (m * V_safe) * ca.sin(alpha_ + delta) + L / (m * V_safe) - g / V_safe * ca.cos(gamma_) + (1 / V_safe) * (Wx_dot * ca.sin(gamma_) - Wh_dot * ca.cos(gamma_))
            alpha_dot = u_

            return ca.vertcat(x_dot, h_dot, V_dot, gamma_dot, alpha_dot)

        J = 0

        # Initial conditions
        opti.subject_to(x_s[:, 0] == 0)
        opti.subject_to(h_s[:, 0] == 600 / hscale)
        opti.subject_to(V_s[:, 0] == 239.7 / Vscale)
        opti.subject_to(gamma_s[:, 0] == -0.03925 / gammascale)
        opti.subject_to(alpha_s[:, 0] == 0.1283 / alphascale)
        opti.subject_to(ca.vec(V_s) >= 1e-2 / Vscale)
        # opti.subject_to(gamma_s[:, -1] == -0.05236 / gammascale)
        opti.subject_to(gamma_s[:, -1] >= 0)
        
        h_ddot_all = [[] for _ in range(N)]
        
        for j in range(M):
            k_val, s_val = nodes[:, j]
            
            i = 0
            dt = 0
            tk = time_grid[i]  # Current time from the time grid
                
            h_physical = h_s[:, i] * hscale
            h_mean = ca.dot(weights_dm, h_physical)

            h_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * h_physical)
            h_high_coeffs = h_pce_coeffs[1:]
            h_std_term = ca.sqrt(ca.sumsqr(h_high_coeffs))

            deviation = hR - h_mean + h_std_term * 12
            scaled_deviation = deviation / hscale
            J += dt * scaled_deviation**6

            Xk = ca.vertcat(x[j, i], h[j, i], V[j, i], gamma[j, i], alpha[j, i])
            Uk = u[i]
            
            # h_ddot = d^2h/dt^2 = V_dot * sin(gamma) + V * cos(gamma) * gamma_dot + Wh_dot
            ode_out = aircraft_ode(Xk, Uk, tk, k_val, s_val)
            x_dot_k = ode_out[0]
            h_dot_k = ode_out[1]
            V_dot_k = ode_out[2]
            gamma_dot_k = ode_out[3]
            # alpha_dot_k = ode_out[4]
            
            dWh_dx_val = dWh_dx_fun(Xk[0], Xk[1], k_val, s_val)[0]
            dWh_dh_val = dWh_dh_fun(Xk[0], Xk[1], k_val, s_val)[0]
            Wh_dot_k = dWh_dx_val * x_dot_k + dWh_dh_val * h_dot_k
            
            h_ddot_k = V_dot_k * ca.sin(Xk[3]) + Xk[2] * ca.cos(Xk[3]) * gamma_dot_k + Wh_dot_k
            
            h_ddot_all[i].append(h_ddot_k)
            
            Xk_end = rk4_step(aircraft_ode, Xk, Uk, tk, dt, k_val, s_val)
            X_next = ca.vertcat(x[j, i+1], h[j, i+1], V[j, i+1], gamma[j, i+1], alpha[j, i+1])
            opti.subject_to(X_next == Xk_end)

            opti.subject_to(opti.bounded(-1, u_s[i], 1))

            alpha_i = alpha_s[:, i] * alphascale
            alpha_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * alpha_i)
            alpha_high_coeffs = alpha_pce_coeffs[1:]
            alpha_mean = ca.dot(weights_dm, alpha_i)
            std_term = ca.sqrt(ca.sumsqr(alpha_high_coeffs))
            
            for i in range(1, N):
                dt = dt_list[i-1]  # Use the time step from the time grid
                tk = time_grid[i]  # Current time from the time grid
                
                h_physical = h_s[:, i] * hscale
                h_mean = ca.dot(weights_dm, h_physical)

                h_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * h_physical)
                h_high_coeffs = h_pce_coeffs[1:]
                h_std_term = ca.sqrt(ca.sumsqr(h_high_coeffs))

                deviation = hR - h_mean + h_std_term * 12
                scaled_deviation = deviation / hscale
                J += dt * scaled_deviation**6

                Xk = ca.vertcat(x[j, i], h[j, i], V[j, i], gamma[j, i], alpha[j, i])
                Uk = u[i]
                
                # h_ddot = d^2h/dt^2 = V_dot * sin(gamma) + V * cos(gamma) * gamma_dot + Wh_dot
                ode_out = aircraft_ode(Xk, Uk, tk, k_val, s_val)
                x_dot_k = ode_out[0]
                h_dot_k = ode_out[1]
                V_dot_k = ode_out[2]
                gamma_dot_k = ode_out[3]
                # alpha_dot_k = ode_out[4]
                
                dWh_dx_val = dWh_dx_fun(Xk[0], Xk[1], k_val, s_val)[0]
                dWh_dh_val = dWh_dh_fun(Xk[0], Xk[1], k_val, s_val)[0]
                Wh_dot_k = dWh_dx_val * x_dot_k + dWh_dh_val * h_dot_k
                
                h_ddot_k = V_dot_k * ca.sin(Xk[3]) + Xk[2] * ca.cos(Xk[3]) * gamma_dot_k + Wh_dot_k
                
                h_ddot_all[i].append(h_ddot_k)
                
                Xk_end = rk4_step(aircraft_ode, Xk, Uk, tk, dt, k_val, s_val)
                X_next = ca.vertcat(x[j, i+1], h[j, i+1], V[j, i+1], gamma[j, i+1], alpha[j, i+1])
                opti.subject_to(X_next == Xk_end)

                opti.subject_to(opti.bounded(-1, u_s[i], 1))

                alpha_i = alpha_s[:, i] * alphascale
                alpha_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * alpha_i)
                alpha_high_coeffs = alpha_pce_coeffs[1:]
                alpha_mean = ca.dot(weights_dm, alpha_i)
                std_term = ca.sqrt(ca.sumsqr(alpha_high_coeffs))

            opti.subject_to(alpha_mean + 3 * std_term <= alphamax)
            opti.subject_to(alpha_mean - 3 * std_term >= -alphamax)
                
        for i in range(N):
            h_ddot_vec = ca.vertcat(*h_ddot_all[i])
            h_ddot_pce_coeffs = ca.mtimes(Psi_dm, weights_dm * h_ddot_vec)
            h_ddot_mean = h_ddot_pce_coeffs[0]
            h_ddot_high_coeffs = h_ddot_pce_coeffs[1:]
            h_ddot_std_term = ca.sqrt(ca.sumsqr(h_ddot_high_coeffs))
            
            opti.subject_to(h_ddot_mean + 3 * h_ddot_std_term <= 10 * g)
            opti.subject_to(h_ddot_mean - 3 * h_ddot_std_term >= -2 * g)

        opti.minimize(J)

        # Initial guess
        for j in range(M):
            opti.set_initial(x_s[j, :], np.linspace(0, 1, N+1))
            opti.set_initial(h_s[j, :], 0.6)  # 600 ft / 1000
            opti.set_initial(V_s[j, :], 239.7 / Vscale)
            opti.set_initial(gamma_s[j, :], -0.01 / gammascale)
            opti.set_initial(alpha_s[j, :], 0.02 / alphascale)
        opti.set_initial(u_s, 0)

        # Solver
        opts = {
            "expand": True,
            "ipopt": {
                # "max_iter": 3000,
                "max_cpu_time": 120,
                "tol": 1e-6,
                "print_level": 0,
                "linear_solver": "mumps",
                "hessian_approximation": "limited-memory",
                # "bound_push": 1e-8,
                # "bound_frac": 1e-8
            }
        }
        opti.solver("ipopt", opts)

        try:
            sol = opti.solve()
        except RuntimeError as e:
            opti.debug.show_infeasibilities()
            print(e)
            return {
                "x": opti.debug.value(x),
                "h": opti.debug.value(h),
                "V": opti.debug.value(V),
                "gamma": opti.debug.value(gamma),
                "alpha": opti.debug.value(alpha),
                "u": opti.debug.value(u),
                "J": opti.debug.value(J),
                "time_grid": time_grid,
                "dt_list": dt_list,
                "status": "failed"
            }

        return {
            "x": sol.value(x),
            "h": sol.value(h),
            "V": sol.value(V),
            "gamma": sol.value(gamma),
            "alpha": sol.value(alpha),
            "u": sol.value(u),
            "J": sol.value(J),
            "time_grid": time_grid,
            "dt_list": dt_list,
            "status": "success"
        }

    def solve_and_refine(time_grid, max_iter=3):
        refined = True
        iter_count = 0
        while refined and iter_count < max_iter:
            sol = solve_ocp(time_grid)
            
            # Check if further refinement is needed
            refined, new_time_grid = refine_time_grid(sol["u"], time_grid, du_tol)
            if refined:
                time_grid = new_time_grid
                iter_count += 1
                print(f"Refining time grid, iteration {iter_count}")
            else:
                break
    
        return sol
    
    return solve_and_refine(time_grid, max_iter=max_iter)

# %%
res_q = solve_wider_wind_ocp_pce_w_adaptive_mesh_q(pce_order=2, k_mean=1.0, k_std=0.08, du_tol=0.01, max_iter=3)
# Out:
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.45ms (103.56us)   4.44ms (103.26us)        43
#        nlp_g  | 213.09ms (  4.96ms) 213.36ms (  4.96ms)        43
#   nlp_grad_f  |   8.32ms (193.58us)   8.31ms (193.15us)        43
#    nlp_jac_g  |   1.03 s ( 23.85ms)   1.03 s ( 23.89ms)        43
#        total  |   2.21 s (  2.21 s)   2.23 s (  2.23 s)         1
# Refining time grid, iteration 1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 448.42ms (129.56us) 448.99ms (129.73us)      3461
#        nlp_g  |  21.12 s (  6.10ms)  21.16 s (  6.11ms)      3461
#   nlp_grad_f  | 392.25ms (238.88us) 392.00ms (238.73us)      1642
#    nlp_jac_g  |  48.98 s ( 29.83ms)  48.86 s ( 29.76ms)      1642
#        total  | 123.24 s (123.24 s) 123.23 s (123.23 s)         1
# Violated constraints (tol 0), in order of declaration:
# ------- i = 0/4241 ------
# 0 <= 6.64559e-27 <= 0 (viol 6.64559e-27)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:224 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 1/4241 ------
# 0 <= 1.86082e-26 <= 0 (viol 1.86082e-26)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:224 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 2/4241 ------
# 0 <= 1.27152e-26 <= 0 (viol 1.27152e-26)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:224 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 3/4241 ------
# 0 <= 1.27899e-26 <= 0 (viol 1.27899e-26)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:224 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4/4241 ------
# 0 <= -4.41187e-26 <= 0 (viol 4.41187e-26)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:224 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 5/4241 ------
# 0 <= 7.28052e-27 <= 0 (viol 7.28052e-27)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:224 in solve_ocp
# At nonzero 5, part 0.
# ------- i = 6/4241 ------
# 0 <= -6.1358e-27 <= 0 (viol 6.1358e-27)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:224 in solve_ocp
# At nonzero 6, part 0.
# ------- i = 7/4241 ------
# 0 <= 8.93542e-27 <= 0 (viol 8.93542e-27)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:224 in solve_ocp
# At nonzero 7, part 0.
# ------- i = 8/4241 ------
# 0 <= -1.67671e-26 <= 0 (viol 1.67671e-26)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:224 in solve_ocp
# At nonzero 8, part 0.
# ------- i = 9/4241 ------
# 0.6 <= 0.6 <= 0.6 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:225 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 10/4241 ------
# 0.6 <= 0.6 <= 0.6 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:225 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 11/4241 ------
# 0.6 <= 0.6 <= 0.6 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:225 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 12/4241 ------
# 0.6 <= 0.6 <= 0.6 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:225 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 13/4241 ------
# 0.6 <= 0.6 <= 0.6 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:225 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 14/4241 ------
# 0.6 <= 0.6 <= 0.6 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:225 in solve_ocp
# At nonzero 5, part 0.
# ------- i = 15/4241 ------
# 0.6 <= 0.6 <= 0.6 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:225 in solve_ocp
# At nonzero 6, part 0.
# ------- i = 16/4241 ------
# 0.6 <= 0.6 <= 0.6 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:225 in solve_ocp
# At nonzero 7, part 0.
# ------- i = 17/4241 ------
# 0.6 <= 0.6 <= 0.6 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:225 in solve_ocp
# At nonzero 8, part 0.
# ------- i = 18/4241 ------
# 0.99875 <= 0.99875 <= 0.99875 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:226 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 19/4241 ------
# 0.99875 <= 0.99875 <= 0.99875 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:226 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 20/4241 ------
# 0.99875 <= 0.99875 <= 0.99875 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:226 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 21/4241 ------
# 0.99875 <= 0.99875 <= 0.99875 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:226 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 22/4241 ------
# 0.99875 <= 0.99875 <= 0.99875 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:226 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 23/4241 ------
# 0.99875 <= 0.99875 <= 0.99875 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:226 in solve_ocp
# At nonzero 5, part 0.
# ------- i = 24/4241 ------
# 0.99875 <= 0.99875 <= 0.99875 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:226 in solve_ocp
# At nonzero 6, part 0.
# ------- i = 25/4241 ------
# 0.99875 <= 0.99875 <= 0.99875 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:226 in solve_ocp
# At nonzero 7, part 0.
# ------- i = 26/4241 ------
# 0.99875 <= 0.99875 <= 0.99875 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:226 in solve_ocp
# At nonzero 8, part 0.
# ------- i = 27/4241 ------
# -0.3925 <= -0.3925 <= -0.3925 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:227 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 28/4241 ------
# -0.3925 <= -0.3925 <= -0.3925 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:227 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 29/4241 ------
# -0.3925 <= -0.3925 <= -0.3925 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:227 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 30/4241 ------
# -0.3925 <= -0.3925 <= -0.3925 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:227 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 31/4241 ------
# -0.3925 <= -0.3925 <= -0.3925 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:227 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 32/4241 ------
# -0.3925 <= -0.3925 <= -0.3925 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:227 in solve_ocp
# At nonzero 5, part 0.
# ------- i = 33/4241 ------
# -0.3925 <= -0.3925 <= -0.3925 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:227 in solve_ocp
# At nonzero 6, part 0.
# ------- i = 34/4241 ------
# -0.3925 <= -0.3925 <= -0.3925 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:227 in solve_ocp
# At nonzero 7, part 0.
# ------- i = 35/4241 ------
# -0.3925 <= -0.3925 <= -0.3925 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:227 in solve_ocp
# At nonzero 8, part 0.
# ------- i = 36/4241 ------
# 0.427667 <= 0.427667 <= 0.427667 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:228 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 37/4241 ------
# 0.427667 <= 0.427667 <= 0.427667 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:228 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 38/4241 ------
# 0.427667 <= 0.427667 <= 0.427667 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:228 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 39/4241 ------
# 0.427667 <= 0.427667 <= 0.427667 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:228 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 40/4241 ------
# 0.427667 <= 0.427667 <= 0.427667 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:228 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 41/4241 ------
# 0.427667 <= 0.427667 <= 0.427667 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:228 in solve_ocp
# At nonzero 5, part 0.
# ------- i = 42/4241 ------
# 0.427667 <= 0.427667 <= 0.427667 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:228 in solve_ocp
# At nonzero 6, part 0.
# ------- i = 43/4241 ------
# 0.427667 <= 0.427667 <= 0.427667 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:228 in solve_ocp
# At nonzero 7, part 0.
# ------- i = 44/4241 ------
# 0.427667 <= 0.427667 <= 0.427667 (viol 0)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:228 in solve_ocp
# At nonzero 8, part 0.
# ------- i = 632/4241 ------
# 0 <= -9.99462e-09 <= inf (viol 9.99462e-09)
# Opti constraint of shape 9x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:231 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 639/4241 ------
# 0 <= 3.27215e-23 <= 0 (viol 3.27215e-23)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:274 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 640/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:274 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 641/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:274 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 642/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:274 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 643/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:274 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 645/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 646/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 647/4241 ------
# 0 <= 2.84217e-14 <= 0 (viol 2.84217e-14)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 648/4241 ------
# 0 <= -6.93889e-18 <= 0 (viol 6.93889e-18)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 649/4241 ------
# 0 <= 2.77556e-17 <= 0 (viol 2.77556e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 650/4241 ------
# -1 <= 1 <= 1 (viol 9.99486e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 651/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 652/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 653/4241 ------
# 0 <= -5.68434e-14 <= 0 (viol 5.68434e-14)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 654/4241 ------
# 0 <= -1.76183e-17 <= 0 (viol 1.76183e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 655/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 656/4241 ------
# -1 <= 1 <= 1 (viol 9.97933e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 657/4241 ------
# 0 <= 5.68434e-14 <= 0 (viol 5.68434e-14)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 658/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 659/4241 ------
# 0 <= 2.84217e-14 <= 0 (viol 2.84217e-14)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 660/4241 ------
# 0 <= 2.77556e-17 <= 0 (viol 2.77556e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 661/4241 ------
# 0 <= -2.77556e-17 <= 0 (viol 2.77556e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 662/4241 ------
# -1 <= 1 <= 1 (viol 9.95972e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 663/4241 ------
# 0 <= 3.22757e-10 <= 0 (viol 3.22757e-10)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 664/4241 ------
# 0 <= 1.187e-09 <= 0 (viol 1.187e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 665/4241 ------
# 0 <= 1.00977e-09 <= 0 (viol 1.00977e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 666/4241 ------
# 0 <= 1.87265e-11 <= 0 (viol 1.87265e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 667/4241 ------
# 0 <= -2.77556e-17 <= 0 (viol 2.77556e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 669/4241 ------
# 0 <= 9.28821e-10 <= 0 (viol 9.28821e-10)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 670/4241 ------
# 0 <= 2.07672e-09 <= 0 (viol 2.07672e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 671/4241 ------
# 0 <= 1.40801e-09 <= 0 (viol 1.40801e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 672/4241 ------
# 0 <= 2.85987e-11 <= 0 (viol 2.85987e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 673/4241 ------
# 0 <= 2.77556e-17 <= 0 (viol 2.77556e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 674/4241 ------
# -1 <= -1 <= 1 (viol 9.95047e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 675/4241 ------
# 0 <= 2.18984e-09 <= 0 (viol 2.18984e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 676/4241 ------
# 0 <= 2.91845e-09 <= 0 (viol 2.91845e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 677/4241 ------
# 0 <= 1.20238e-09 <= 0 (viol 1.20238e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 678/4241 ------
# 0 <= 2.95366e-11 <= 0 (viol 2.95366e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 679/4241 ------
# 0 <= -2.77556e-17 <= 0 (viol 2.77556e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 680/4241 ------
# -1 <= -1 <= 1 (viol 9.96618e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 681/4241 ------
# 0 <= 4.25541e-09 <= 0 (viol 4.25541e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 682/4241 ------
# 0 <= 4.31976e-09 <= 0 (viol 4.31976e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 683/4241 ------
# 0 <= 8.78885e-10 <= 0 (viol 8.78885e-10)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 684/4241 ------
# 0 <= 3.06726e-11 <= 0 (viol 3.06726e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 685/4241 ------
# 0 <= -1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 686/4241 ------
# -1 <= -1 <= 1 (viol 9.97065e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 687/4241 ------
# 0 <= 7.28971e-09 <= 0 (viol 7.28971e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 688/4241 ------
# 0 <= 6.37158e-09 <= 0 (viol 6.37158e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 689/4241 ------
# 0 <= 3.688e-10 <= 0 (viol 3.688e-10)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 690/4241 ------
# 0 <= 3.18346e-11 <= 0 (viol 3.18346e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 691/4241 ------
# 0 <= 1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 692/4241 ------
# -1 <= -1 <= 1 (viol 9.96987e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 693/4241 ------
# 0 <= 2.82967e-08 <= 0 (viol 2.82967e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 694/4241 ------
# 0 <= 2.52415e-08 <= 0 (viol 2.52415e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 695/4241 ------
# 0 <= -2.23184e-09 <= 0 (viol 2.23184e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 696/4241 ------
# 0 <= 6.60187e-11 <= 0 (viol 6.60187e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 697/4241 ------
# 0 <= -1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 698/4241 ------
# -1 <= -1 <= 1 (viol 9.97796e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 699/4241 ------
# 0 <= 5.1348e-08 <= 0 (viol 5.1348e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 700/4241 ------
# 0 <= 3.55318e-08 <= 0 (viol 3.55318e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 701/4241 ------
# 0 <= -7.5311e-09 <= 0 (viol 7.5311e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 702/4241 ------
# 0 <= 6.93938e-13 <= 0 (viol 6.93938e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 703/4241 ------
# 0 <= 1.73472e-18 <= 0 (viol 1.73472e-18)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 705/4241 ------
# 0 <= 2.91293e-08 <= 0 (viol 2.91293e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 706/4241 ------
# 0 <= 1.97903e-08 <= 0 (viol 1.97903e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 707/4241 ------
# 0 <= -3.82462e-09 <= 0 (viol 3.82462e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 708/4241 ------
# 0 <= -2.0181e-11 <= 0 (viol 2.0181e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 709/4241 ------
# 0 <= -6.93889e-18 <= 0 (viol 6.93889e-18)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 710/4241 ------
# -1 <= 1 <= 1 (viol 9.94136e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 711/4241 ------
# 0 <= 2.84429e-08 <= 0 (viol 2.84429e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 712/4241 ------
# 0 <= 2.15159e-08 <= 0 (viol 2.15159e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 713/4241 ------
# 0 <= -3.26278e-09 <= 0 (viol 3.26278e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 714/4241 ------
# 0 <= -1.87348e-11 <= 0 (viol 1.87348e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 715/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 716/4241 ------
# -1 <= 1 <= 1 (viol 9.96092e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 717/4241 ------
# 0 <= 2.7035e-08 <= 0 (viol 2.7035e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 718/4241 ------
# 0 <= 2.29669e-08 <= 0 (viol 2.29669e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 719/4241 ------
# 0 <= -2.64464e-09 <= 0 (viol 2.64464e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 720/4241 ------
# 0 <= -1.50353e-11 <= 0 (viol 1.50353e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 721/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 722/4241 ------
# -1 <= 1 <= 1 (viol 9.96776e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 723/4241 ------
# 0 <= 2.48335e-08 <= 0 (viol 2.48335e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 724/4241 ------
# 0 <= 2.38502e-08 <= 0 (viol 2.38502e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 725/4241 ------
# 0 <= -2.04963e-09 <= 0 (viol 2.04963e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 726/4241 ------
# 0 <= -9.89561e-12 <= 0 (viol 9.89561e-12)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 727/4241 ------
# 0 <= 1.38778e-17 <= 0 (viol 1.38778e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 728/4241 ------
# -1 <= 1 <= 1 (viol 9.96996e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 729/4241 ------
# 0 <= 3.97031e-08 <= 0 (viol 3.97031e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 730/4241 ------
# 0 <= 4.60426e-08 <= 0 (viol 4.60426e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 731/4241 ------
# 0 <= -2.37753e-09 <= 0 (viol 2.37753e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 732/4241 ------
# 0 <= -4.53812e-12 <= 0 (viol 4.53812e-12)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 733/4241 ------
# 0 <= -2.77556e-17 <= 0 (viol 2.77556e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 734/4241 ------
# -1 <= 1 <= 1 (viol 9.9843e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 735/4241 ------
# 0 <= 2.49661e-08 <= 0 (viol 2.49661e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 736/4241 ------
# 0 <= 3.96822e-08 <= 0 (viol 3.96822e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 737/4241 ------
# 0 <= -5.39842e-10 <= 0 (viol 5.39842e-10)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 738/4241 ------
# 0 <= 1.03919e-11 <= 0 (viol 1.03919e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 739/4241 ------
# 0 <= 5.55112e-17 <= 0 (viol 5.55112e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 740/4241 ------
# -1 <= 1 <= 1 (viol 9.98057e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 741/4241 ------
# 0 <= 1.1119e-08 <= 0 (viol 1.1119e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 742/4241 ------
# 0 <= 2.62052e-08 <= 0 (viol 2.62052e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 743/4241 ------
# 0 <= 1.78179e-09 <= 0 (viol 1.78179e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 744/4241 ------
# 0 <= 4.41919e-12 <= 0 (viol 4.41919e-12)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 745/4241 ------
# 0 <= -5.55112e-17 <= 0 (viol 5.55112e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 746/4241 ------
# -1 <= 1 <= 1 (viol 9.97378e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 747/4241 ------
# 0 <= 3.02998e-09 <= 0 (viol 3.02998e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 748/4241 ------
# 0 <= 1.15165e-08 <= 0 (viol 1.15165e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 749/4241 ------
# 0 <= 3.80788e-09 <= 0 (viol 3.80788e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 750/4241 ------
# 0 <= -2.40743e-11 <= 0 (viol 2.40743e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 751/4241 ------
# 0 <= 5.55112e-17 <= 0 (viol 5.55112e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 752/4241 ------
# -1 <= 1 <= 1 (viol 9.96039e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 753/4241 ------
# 0 <= 4.1864e-09 <= 0 (viol 4.1864e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 754/4241 ------
# 0 <= 4.66736e-09 <= 0 (viol 4.66736e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 755/4241 ------
# 0 <= 2.58851e-09 <= 0 (viol 2.58851e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 756/4241 ------
# 0 <= -5.06518e-11 <= 0 (viol 5.06518e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 757/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 758/4241 ------
# -1 <= 1 <= 1 (viol 9.91876e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 759/4241 ------
# 0 <= 1.50339e-08 <= 0 (viol 1.50339e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 760/4241 ------
# 0 <= 9.7258e-09 <= 0 (viol 9.7258e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 761/4241 ------
# 0 <= -3.1645e-09 <= 0 (viol 3.1645e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 762/4241 ------
# 0 <= -1.9418e-11 <= 0 (viol 1.9418e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 763/4241 ------
# 0 <= -5.55112e-17 <= 0 (viol 5.55112e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 764/4241 ------
# -1 <= -1 <= 1 (viol 4.52432e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 765/4241 ------
# 0 <= 1.4476e-08 <= 0 (viol 1.4476e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 766/4241 ------
# 0 <= 7.30398e-09 <= 0 (viol 7.30398e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 767/4241 ------
# 0 <= 5.97454e-08 <= 0 (viol 5.97454e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 768/4241 ------
# 0 <= -8.77035e-11 <= 0 (viol 8.77035e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 769/4241 ------
# 0 <= 5.55112e-17 <= 0 (viol 5.55112e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 770/4241 ------
# -1 <= -1 <= 1 (viol 9.77914e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 771/4241 ------
# 0 <= 6.67305e-08 <= 0 (viol 6.67305e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 772/4241 ------
# 0 <= -2.26635e-10 <= 0 (viol 2.26635e-10)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 773/4241 ------
# 0 <= 5.39738e-08 <= 0 (viol 5.39738e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 774/4241 ------
# 0 <= -3.67677e-11 <= 0 (viol 3.67677e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 775/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 776/4241 ------
# -1 <= -1 <= 1 (viol 9.8152e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 777/4241 ------
# 0 <= 4.45079e-08 <= 0 (viol 4.45079e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 778/4241 ------
# 0 <= 3.17419e-09 <= 0 (viol 3.17419e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 779/4241 ------
# 0 <= 2.65803e-09 <= 0 (viol 2.65803e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 780/4241 ------
# 0 <= 4.85844e-11 <= 0 (viol 4.85844e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 781/4241 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 782/4241 ------
# -1 <= -1 <= 1 (viol 9.73846e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 783/4241 ------
# 0 <= 4.63733e-08 <= 0 (viol 4.63733e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 784/4241 ------
# 0 <= 8.6402e-10 <= 0 (viol 8.6402e-10)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 785/4241 ------
# 0 <= 1.70928e-08 <= 0 (viol 1.70928e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 786/4241 ------
# 0 <= 5.95147e-11 <= 0 (viol 5.95147e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 787/4241 ------
# 0 <= -2.77556e-17 <= 0 (viol 2.77556e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 789/4241 ------
# 0 <= 4.09786e-08 <= 0 (viol 4.09786e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 790/4241 ------
# 0 <= -1.65426e-09 <= 0 (viol 1.65426e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 791/4241 ------
# 0 <= 2.72476e-08 <= 0 (viol 2.72476e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 792/4241 ------
# 0 <= 4.96498e-11 <= 0 (viol 4.96498e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 793/4241 ------
# 0 <= 5.55112e-17 <= 0 (viol 5.55112e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 794/4241 ------
# -1 <= 1 <= 1 (viol 9.82895e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 795/4241 ------
# 0 <= 3.20215e-08 <= 0 (viol 3.20215e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 796/4241 ------
# 0 <= -2.61036e-09 <= 0 (viol 2.61036e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 797/4241 ------
# 0 <= -6.83258e-10 <= 0 (viol 6.83258e-10)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 798/4241 ------
# 0 <= -2.26023e-11 <= 0 (viol 2.26023e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 799/4241 ------
# 0 <= -5.55112e-17 <= 0 (viol 5.55112e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 800/4241 ------
# -1 <= 1 <= 1 (viol 9.92889e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 801/4241 ------
# 0 <= 3.11338e-08 <= 0 (viol 3.11338e-08)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 802/4241 ------
# 0 <= 2.42431e-09 <= 0 (viol 2.42431e-09)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 803/4241 ------
# 0 <= -6.72827e-10 <= 0 (viol 6.72827e-10)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 804/4241 ------
# 0 <= -2.49697e-11 <= 0 (viol 2.49697e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 805/4241 ------
# 0 <= -5.55112e-17 <= 0 (viol 5.55112e-17)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 806/4241 ------
# -1 <= 1 <= 1 (viol 9.95979e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 807/4241 ------
# ...
# At nonzero 2, part 0.
# ------- i = 4735/4956 ------
# 0 <= -5.0307e-16 <= 0 (viol 5.0307e-16)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4736/4956 ------
# 0 <= -1.88738e-15 <= 0 (viol 1.88738e-15)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4738/4956 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4739/4956 ------
# 0 <= -1.67688e-11 <= 0 (viol 1.67688e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4740/4956 ------
# 0 <= 1.13687e-13 <= 0 (viol 1.13687e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4741/4956 ------
# 0 <= 2.07473e-15 <= 0 (viol 2.07473e-15)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4742/4956 ------
# 0 <= 3.66374e-15 <= 0 (viol 3.66374e-15)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4743/4956 ------
# -1 <= -1 <= 1 (viol 4.22308e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4744/4956 ------
# 0 <= 4.54747e-12 <= 0 (viol 4.54747e-12)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4745/4956 ------
# 0 <= -1.61435e-11 <= 0 (viol 1.61435e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4746/4956 ------
# 0 <= -2.84217e-13 <= 0 (viol 2.84217e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4747/4956 ------
# 0 <= -2.64372e-15 <= 0 (viol 2.64372e-15)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4748/4956 ------
# 0 <= 1.44329e-15 <= 0 (viol 1.44329e-15)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4749/4956 ------
# -1 <= -1 <= 1 (viol 6.36938e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4750/4956 ------
# 0 <= 5.45697e-12 <= 0 (viol 5.45697e-12)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4751/4956 ------
# 0 <= -1.5234e-11 <= 0 (viol 1.5234e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4752/4956 ------
# 0 <= -1.13687e-13 <= 0 (viol 1.13687e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4753/4956 ------
# 0 <= -5.14866e-15 <= 0 (viol 5.14866e-15)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4754/4956 ------
# 0 <= -4.996e-15 <= 0 (viol 4.996e-15)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4755/4956 ------
# -1 <= -1 <= 1 (viol 7.47741e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4756/4956 ------
# 0 <= 7.27596e-12 <= 0 (viol 7.27596e-12)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4757/4956 ------
# 0 <= -1.42677e-11 <= 0 (viol 1.42677e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4758/4956 ------
# 0 <= -2.27374e-13 <= 0 (viol 2.27374e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4759/4956 ------
# 0 <= -8.49321e-15 <= 0 (viol 8.49321e-15)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4760/4956 ------
# 0 <= 4.996e-15 <= 0 (viol 4.996e-15)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4761/4956 ------
# -1 <= -1 <= 1 (viol 8.13095e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4762/4956 ------
# 0 <= 1.63709e-11 <= 0 (viol 1.63709e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4763/4956 ------
# 0 <= -2.38742e-11 <= 0 (viol 2.38742e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4764/4956 ------
# 0 <= -4.54747e-13 <= 0 (viol 4.54747e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4765/4956 ------
# 0 <= -2.80331e-14 <= 0 (viol 2.80331e-14)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4766/4956 ------
# 0 <= 6.66134e-16 <= 0 (viol 6.66134e-16)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4767/4956 ------
# -1 <= -1 <= 1 (viol 9.35505e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4768/4956 ------
# 0 <= 2.18279e-11 <= 0 (viol 2.18279e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4769/4956 ------
# 0 <= -1.68825e-11 <= 0 (viol 1.68825e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4770/4956 ------
# 0 <= -9.37916e-13 <= 0 (viol 9.37916e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4771/4956 ------
# 0 <= -4.03011e-14 <= 0 (viol 4.03011e-14)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4772/4956 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4773/4956 ------
# -1 <= -1 <= 1 (viol 9.56219e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4774/4956 ------
# 0 <= 4.72937e-11 <= 0 (viol 4.72937e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4775/4956 ------
# 0 <= -1.33014e-11 <= 0 (viol 1.33014e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4776/4956 ------
# 0 <= -1.02318e-12 <= 0 (viol 1.02318e-12)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4777/4956 ------
# 0 <= -1.04361e-13 <= 0 (viol 1.04361e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4778/4956 ------
# 0 <= -2.22045e-16 <= 0 (viol 2.22045e-16)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4779/4956 ------
# -1 <= -1 <= 1 (viol 9.85924e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4780/4956 ------
# 0 <= 4.54747e-11 <= 0 (viol 4.54747e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4781/4956 ------
# 0 <= 1.72804e-11 <= 0 (viol 1.72804e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4782/4956 ------
# 0 <= -5.11591e-13 <= 0 (viol 5.11591e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4783/4956 ------
# 0 <= -1.10328e-13 <= 0 (viol 1.10328e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4784/4956 ------
# 0 <= 2.77556e-16 <= 0 (viol 2.77556e-16)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4785/4956 ------
# -1 <= -1 <= 1 (viol 9.90723e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4786/4956 ------
# 0 <= 3.81988e-11 <= 0 (viol 3.81988e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4787/4956 ------
# 0 <= 4.1382e-11 <= 0 (viol 4.1382e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4788/4956 ------
# 0 <= 1.13687e-13 <= 0 (viol 1.13687e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4789/4956 ------
# 0 <= -8.06855e-14 <= 0 (viol 8.06855e-14)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4790/4956 ------
# 0 <= 8.32667e-16 <= 0 (viol 8.32667e-16)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4791/4956 ------
# -1 <= -1 <= 1 (viol 9.93097e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4792/4956 ------
# 0 <= 2.00089e-11 <= 0 (viol 2.00089e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4793/4956 ------
# 0 <= 5.41149e-11 <= 0 (viol 5.41149e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4794/4956 ------
# 0 <= 4.26326e-13 <= 0 (viol 4.26326e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4795/4956 ------
# 0 <= -2.53339e-14 <= 0 (viol 2.53339e-14)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4796/4956 ------
# 0 <= -1.66533e-16 <= 0 (viol 1.66533e-16)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4797/4956 ------
# -1 <= -1 <= 1 (viol 9.94464e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4798/4956 ------
# 0 <= 3.63798e-12 <= 0 (viol 3.63798e-12)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 0, part 0.
# ------- i = 4799/4956 ------
# 0 <= 5.34897e-11 <= 0 (viol 5.34897e-11)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 1, part 0.
# ------- i = 4800/4956 ------
# 0 <= 4.26326e-13 <= 0 (viol 4.26326e-13)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 2, part 0.
# ------- i = 4801/4956 ------
# 0 <= 3.18747e-14 <= 0 (viol 3.18747e-14)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 3, part 0.
# ------- i = 4802/4956 ------
# 0 <= 0 <= 0 (viol 0)
# Opti constraint of shape 5x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:320 in solve_ocp
# At nonzero 4, part 0.
# ------- i = 4803/4956 ------
# -1 <= 1 <= 1 (viol 9.48097e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:322 in solve_ocp
# ------- i = 4804/4956 ------
# -inf <= 0.3 <= 0.3 (viol 9.99765e-09)
# Opti constraint of shape 1x1, called from /var/folders/28/lyrrcllj2r1bxh2z60vqsh400000gn/T/ipykernel_65566/2815753469.py:330 in solve_ocp
# Error in Opti::solve [OptiNode] at .../casadi/core/optistack.cpp:217:
# .../casadi/core/optistack_internal.cpp:1336: Assertion "return_success(accept_limit)" failed:
# Solver failed. You may use opti.debug.value to investigate the latest values of variables. return_status is 'Maximum_CpuTime_Exceeded'
# Refining time grid, iteration 3
